# %% [markdown]
# # Regular Expressions Tutorial: Parse Addresses with Python
#
#
# with `Mr. Fugu Data Science`
#
# # (◕‿◕✿)
#
#
# [Github](https://github.com/MrFuguDataScience) | [Youtube](https://www.youtube.com/channel/UCbni-TDI-Ub8VlGaP8HLTNw?view_as=subscriber)

# %% [markdown]
# [re module documentation](https://docs.python.org/3/library/re.html)
#
# |     	|                                             	|   	| Special Characters 	|                                                                 	|
# |-----	|---------------------------------------------	|---	|--------------------	|-----------------------------------------------------------------	|
# | \A  	| matches start of string                     	|   	| .                  	| any character except (\n)                                       	|
# | \b  	| boundary of  word                           	|   	| ^                  	| start of string, except for multiline it matches directly after 	|
# | \B  	| Not Word Boundary                           	|   	| $                  	| end of string or just before (\n)                               	|
# | \d  	| digits: (0-9)                               	|   	| *                  	| 0+, repetitions of pattern before the (*)                       	|
# | \D  	| any character but NOT digit                 	|   	| +                  	| 1+ repetitions of pattern before the (+)                        	|
# | \s  	| whitespace: (\t,\n, space)                  	|   	| ?                  	| 0 or 1 repetitions preceding RE.                                	|
# | \S  	| matches any character but NOT (\t,\n space) 	|   	| *?, +?, ??         	| Creates non greedy forms                                        	|
# | \w  	| matches characters,  digits, underscore     	|   	| {m}                	| exact number of matches                                         	|
# | \W  	| anything except  character                  	|   	| {m.n}              	| range of matches                                                	|
# | \Z  	| Only matches end of string                  	|   	| {m,n}?             	| match as FEW as possible, in range                              	|
# | ( ) 	| grouping                                    	|   	| [ ]                	| Character set, finds anything inside                            	|
#
#
# `---------------------------------------`
#
# `Other Tips:`
#
# | Look ahead &  Look Behind 	|                                                                                                                           	|
# |---------------------------	|---------------------------------------------------------------------------------------------------------------------------	|
# | ?:                        	| match but don't capture it                                                                                                	|
# | ?=                        	| match suffix but exclude from capture "Look ahead" ex.) q(?=u), find "q" that IS followed by "u", BUT, doesn't return "u" 	|
# | ?!                        	| match if suffix is absent (neg.) look ahead ex.) p(?!u), means find "p" NOT  followed by "u"                              	|
# | ?<=                       	| positive look ahead                                                                                                       	|
# | ?<!                       	| negative look behind                                                                                                      	|
# | (?=(regex))               	| use this to store the data from look ahead                                                                                	|

# %%
import re
import pandas as pd
# from bs4 import BeautifulStoneSoup as bsopa
# from selenium import webdriver
# import requests
import faker

# %%
fake_=faker.Faker()
fake_.seed(413)
fake_personal_profile=[]
for i in range(500):
    fake_personal_profile.append(fake_.profile())
    


# use if you were only if you were taking 1 item from dictionary-list
# pd.DataFrame(fake_personal_profile,orient='index').transpose()

# %% [markdown]
# # Creating Personal Profiles with Fake Data:

# %%
# Personal Data for Fake People:
fake_persons_data=pd.DataFrame(fake_personal_profile)

blood_type=fake_persons_data['blood_group']

fake_persons_data['residence'][4].split(' ')
# fake_persons_data
# Out:
# ['36411', 'Schwartz', 'Shoals', 'Suite', '648\nEast', 'Denise,', 'NV', '66145']

# %%
fake_persons_data['residence'][0]
# Out:
# '74187 Laurie Parkways Apt. 344\nLake Maria, MN 77577'

# %%
# Change BOX to PO BOX:

update_pobox=[]
for i in fake_persons_data['residence']: 
    op=re.sub(r'Box', 'PO BOX',i)
    update_pobox.append(op)
    
update_pobox
# Out:
# ['74187 Laurie Parkways Apt. 344\nLake Maria, MN 77577',
#  '4035 Perez Pass Apt. 421\nCalderonton, KS 89435',
#  '0086 Cohen Trafficway\nNorth Joseph, WV 50669',
#  '4637 Mary Inlet Apt. 200\nNew Robert, ME 48035',
#  '36411 Schwartz Shoals Suite 648\nEast Denise, NV 66145',
#  '811 Johnson Garden Suite 506\nYolandafort, RI 63534',
#  '976 Amanda Common Suite 647\nChristianchester, VT 25717',
#  'USNV Maddox\nFPO AA 77402',
#  '0259 Douglas Gardens\nNew Aliciaberg, NM 73609',
#  '372 Wilson Common\nLake Latasha, MA 90202',
#  '667 Andrea Divide Suite 768\nRubenbury, RI 76156',
#  '81186 Frank Ports Suite 654\nDebrafort, NE 47710',
#  '6325 Morse Pine Apt. 801\nRobertoburgh, MN 50010',
#  '5266 Hart Burgs Suite 937\nMoorebury, MO 58963',
#  '804 Hester Station Suite 574\nEast John, OH 02675',
#  '227 Melissa Fields Suite 756\nDavidborough, OH 69897',
#  '906 Karen Loaf\nLake Jason, NY 87552',
#  '5517 Teresa Drive\nEast Mason, TN 57993',
#  '5702 Joshua Alley Suite 392\nBryanthaven, WY 33452',
#  '499 Michael Shores\nSouth Brenda, AR 44326',
#  '8309 Nichols Ford Apt. 391\nWilliambury, LA 67738',
#  '683 Nunez Parkway Suite 561\nOdonnellborough, NE 81031',
#  '8679 Young Stravenue Suite 338\nWestview, FL 29654',
#  '89049 Jessica Road\nWest Meagan, OH 88771',
#  '2694 Mcmillan Light Suite 626\nWangchester, CO 59661',
#  '63991 Lee Station\nClarencetown, DC 37301',
#  '0384 Carrie Mills\nChanburgh, MT 24541',
#  '239 Nichole Station\nEast Cameron, MS 80908',
#  '082 Hood Passage Suite 334\nDawnmouth, SD 10335',
#  '36121 Travis Forks Apt. 236\nNew Paigechester, OR 96454',
#  '927 Donald Turnpike\nLake Edwardmouth, CT 14757',
#  '982 Avery Track Suite 934\nOconnellside, LA 30835',
#  '1283 Jonathan Springs\nVictoriaport, WV 88955',
#  '007 Carla Parkway\nPorterbury, NJ 83519',
#  '2465 Gerald Mews\nPort Michael, NM 77520',
#  '067 Adam Ville Suite 997\nWest Derrickborough, MI 35864',
#  '93956 Steven View Apt. 748\nWest Andrea, MS 47690',
#  '6071 Zachary Mall\nNorth Grace, FL 15686',
#  '8106 Contreras Landing\nEast Stephanieshire, AK 90567',
#  '64316 Jennifer Fort Suite 264\nWest Nicolasfort, GA 97504',
#  '941 Jeremy Rest Apt. 486\nEast Allison, MD 48851',
#  '778 Steve Key\nLake Chad, KS 81740',
#  '0051 Smith Throughway Apt. 996\nPort Donna, OH 15666',
#  '9851 Anderson Mills Suite 176\nEast Luke, LA 85007',
#  '8010 Ramirez Club Apt. 824\nSouth Johnhaven, MA 37605',
#  '8487 Lawrence Unions Apt. 567\nKellyberg, DE 81275',
#  '41419 Aguilar Throughway\nEast Jeffreyborough, LA 42663',
#  '937 Amy Square Apt. 487\nCrystalshire, MS 78445',
#  'PSC 5627, PO BOX 8534\nAPO AP 26601',
#  '823 Hamilton Forges\nLake Dennis, NM 86895',
#  '6079 Mahoney Highway\nNew Gary, OK 84354',
#  '84788 Campos Pike\nFreemanstad, WV 61997',
#  '450 Brian Passage\nNorth Jamesville, SC 15291',
#  '92345 Terrence Green\nLake Cynthia, WI 72609',
#  '9526 Keith Mountains\nJulieborough, NE 74563',
#  '315 Brandon Harbors\nEast Benjaminland, MI 57476',
#  '3784 Chen Estate\nEast Carmen, HI 93102',
#  '255 Camacho Street Apt. 674\nJimmyport, AL 29627',
#  '2257 Samantha Track Suite 699\nNorth Laurie, TN 68112',
#  '48146 Martin Shore\nChristopherland, TX 75493',
#  'Unit 7862 PO BOX 1281\nDPO AA 94969',
#  '9301 Gregory Center\nHooperbury, MS 64382',
#  '7752 Garner Bypass\nLake Cristianview, VT 47099',
#  '775 Frank Gateway Suite 399\nTapiamouth, FL 87450',
#  '632 Macdonald Locks Apt. 126\nSouth Joseph, NE 60938',
#  '24765 Gregory Haven\nLeemouth, NJ 94248',
#  '80956 Julia Centers Apt. 765\nNew Lisa, TN 59234',
#  '78599 Scott Centers\nLake Maurice, MN 38430',
#  '886 Hall Streets\nEast Michael, MA 32110',
#  '7104 Jackson Throughway\nPort Miguelburgh, MO 58453',
#  '8223 Brian Summit\nWebbburgh, ME 43060',
#  '197 Rose Cape\nPort Meganhaven, DE 44288',
#  '4174 Corey Union Apt. 731\nBethanyview, AK 76453',
#  '23770 Murphy Ridges Suite 546\nEast Johnchester, UT 08945',
#  '501 Mitchell Flats Apt. 808\nKylebury, NM 77480',
#  '35345 Moore Plains Suite 101\nNew Lindaborough, ND 64886',
#  '8285 Vanessa Bypass Suite 779\nAnnetteberg, MI 73041',
#  '99739 Ashley Rue\nAlvaradochester, MD 59304',
#  '34554 Hoffman Street\nLisatown, AK 72249',
#  '958 Moody Mount Apt. 787\nCrystalhaven, SD 08559',
#  '84025 Steele Neck Suite 578\nNew Jacob, NE 96300',
#  '53853 Torres Ports\nNew Bethberg, RI 53889',
#  'USNV Lewis\nFPO AA 92743',
#  '741 Mario Extension Apt. 219\nJacksonborough, NV 46391',
#  '284 Meghan Way\nWagnerbury, CO 56330',
#  '18877 Perez Burg\nDiazberg, MN 37514',
#  '73318 Anderson Passage Apt. 976\nNew Ryan, VT 99408',
#  '353 Andrew Estates Apt. 598\nLewismouth, WY 37460',
#  'Unit 0606 PO BOX 5467\nDPO AA 47518',
#  '602 Scott Flats\nWest Brian, MS 19093',
#  '0260 Williams Glen Apt. 745\nEast Nicholas, CT 41968',
#  '02024 Elizabeth Fords Suite 697\nJohnstonchester, MD 69392',
#  '8901 Jennifer Fields\nJosephbury, SC 15238',
#  '3541 Vega Prairie Apt. 067\nPort Leahmouth, DC 52797',
#  '25873 Gomez Key Suite 172\nLake Shellyton, IN 06390',
#  '567 April Manor\nRiveraville, NE 51210',
#  '21794 Brandi Spur\nNorth Kristin, NY 07562',
#  '43833 Smith Pass\nNew Scott, CA 91552',
#  '42469 Lloyd Isle Suite 177\nNew Deborahfort, DE 26666',
#  'Unit 5595 PO BOX 4398\nDPO AP 46797',
#  '799 Pena Squares Suite 567\nEast Rodneyfort, CT 37704',
#  'Unit 6115 PO BOX 3043\nDPO AP 95323',
#  '303 Cindy Springs Suite 588\nFernandezland, WI 87118',
#  '477 Tammy Fall Suite 288\nNavarroton, VT 87014',
#  '305 Gray Inlet\nStephanieton, GA 64285',
#  '134 Wagner Street\nWilliamsbury, IA 75602',
#  '476 Potter Roads\nDeckerhaven, MD 92255',
#  '910 Green Run\nHollowaybury, RI 55379',
#  '7549 Salinas Meadow Apt. 147\nHortonstad, AL 30887',
#  '869 Patrick Lock\nStrongmouth, ID 67242',
#  '58902 Brenda Shoal Apt. 406\nLake Michael, AK 92604',
#  '1529 Moore Lock\nEast Jessicaborough, IL 29749',
#  '5671 Brent Lake\nJamesbury, DE 63032',
#  '15842 Kathy Island Suite 667\nGabriellaville, MD 55348',
#  '146 Baker Vista Suite 132\nLake Louisland, MO 98682',
#  '78159 Andrews Plaza\nCoxberg, TX 04469',
#  'USNV Wu\nFPO AE 47182',
#  '3694 Marcus Crest Suite 900\nStuartborough, MA 62279',
#  '96479 Perez Ville Suite 873\nWalkerberg, CA 97733',
#  '643 Clarke Manors Apt. 056\nEast Michaelland, MO 39259',
#  'Unit 3713 PO BOX 4542\nDPO AA 52134',
#  '4923 Toni Lane\nKyleport, KS 09837',
#  '3408 Sarah Stravenue Suite 528\nLake Jonathanshire, WV 99177',
#  '486 Taylor Ways Apt. 443\nBurchborough, AZ 11143',
#  '39204 Spencer Coves Apt. 857\nEast Brandon, IN 69031',
#  '02806 Noah Mountains\nJasonburgh, MO 27388',
#  '62568 Rush Point\nNew Cameron, GA 20222',
#  '0619 Steven Crest\nVictorfort, WA 58860',
#  '710 Felicia Dam\nHartmanport, SD 37384',
#  'PSC 3664, PO BOX 6311\nAPO AP 47554',
#  '9717 Kelly Ports\nAlisonside, NH 95813',
#  '917 David Locks Suite 044\nLake Jamieport, NE 60827',
#  '658 Drake Street Apt. 900\nSouth Frankshire, MS 19961',
#  '6079 Travis Trace Apt. 000\nWest Joshuaville, NC 98345',
#  '07725 Melinda Squares Apt. 377\nEast Amyfurt, OK 69416',
#  '546 Sawyer Summit Apt. 600\nLopezville, RI 71955',
#  '52857 Lewis Extension\nKevinton, AR 34667',
#  '160 Brooke Wells Suite 758\nWilsonchester, ND 83410',
#  '57891 Foley Burgs\nNorth Ashley, AZ 63751',
#  '2898 Justin Mall\nPort Cherylhaven, TX 58787',
#  '8022 Bray Harbors\nHesterfurt, TN 30095',
#  '2236 Benjamin Tunnel Apt. 190\nNew Courtneybury, SD 87573',
#  '889 Michael Park\nNorrismouth, CT 64653',
#  '8099 Fuentes Oval\nGarciaborough, KY 50446',
#  '39403 Edwards Ways Apt. 567\nMelindaberg, MD 44325',
#  '133 Antonio Estates Apt. 367\nFoxshire, NC 86707',
#  '719 Sara Villages\nJustinmouth, NH 36813',
#  '9711 Timothy Neck Suite 727\nMadisonbury, OH 77458',
#  '995 Morgan Lodge\nAndersonview, GA 94018',
#  'Unit 8892 PO BOX 8309\nDPO AP 53729',
#  '95454 Kimberly Forest Apt. 522\nNguyenshire, MA 49938',
#  '192 Miller Harbors Apt. 666\nRickchester, OH 77901',
#  '3739 Jason Island Suite 484\nBrownshire, ME 32960',
#  '5185 John Forges Apt. 083\nHallton, UT 58189',
#  '887 Hayes Divide\nSouth Kellyport, KY 03217',
#  '9005 Michael Union\nRhondaton, CA 73750',
#  'Unit 1201 PO BOX 3369\nDPO AE 43434',
#  '2711 Jasmine Inlet\nPort Kayla, WI 17939',
#  '7517 Powell Points Suite 892\nBestfurt, ID 49545',
#  '82143 Pittman Lights\nWest Paul, CO 92690',
#  '606 Kathleen Square\nEast Shaneberg, MN 37391',
#  '0761 George Garden\nRojasstad, WA 62820',
#  '71018 Matthew Well Apt. 571\nMooreview, KS 38167',
#  '4093 Michael Plains\nWest Christine, WA 89000',
#  'USNV Sloan\nFPO AP 06977',
#  '3750 Sanders Garden\nEast Amanda, WY 62208',
#  '4056 Molly Falls\nWest Brianmouth, PA 46280',
#  'PSC 7690, PO BOX 4320\nAPO AP 64302',
#  '6378 Pearson Lakes\nRobertschester, OR 66112',
#  '31366 Lopez Circles\nChristopherview, NH 90065',
#  '95168 Katherine Gardens\nMooreland, NM 10210',
#  '588 Carter Mission Suite 606\nSouth Christopher, OH 75072',
#  '7293 Jennifer Drives\nJosephborough, AZ 53348',
#  '5026 Duran Motorway Suite 434\nAndreabury, AL 12926',
#  '934 Foster Creek\nNorth Roberttown, ME 62705',
#  '72952 Wheeler Forks\nTurnermouth, NM 17467',
#  '248 Sanders Fields Apt. 230\nMarytown, MA 26192',
#  '03317 Fuller Falls\nLake Christopher, MD 60015',
#  '4872 Guzman Prairie\nPort Joseph, DC 91142',
#  '456 Reyes Path\nSouth Crystaltown, NC 27087',
#  'PSC 8593, PO BOX 6015\nAPO AE 35452',
#  '47113 David Lake Suite 697\nDavidside, TN 84401',
#  '6779 Marie Vista Apt. 772\nBarnesstad, ID 47897',
#  '591 Paula Trace\nPort Mariahaven, NM 47716',
#  '8704 Williams Bridge\nSellersport, IL 14704',
#  '41700 Smith Port Apt. 857\nPort Shawnville, CT 32722',
#  '803 Kathleen Lodge Apt. 756\nNew Charles, NV 12104',
#  '916 Meadows Route Apt. 748\nCollinsberg, MT 58671',
#  '6242 Gabriel Flat Apt. 868\nDeleonland, NH 79429',
#  '62595 Tyler Extensions Apt. 327\nRyantown, ME 10934',
#  '69958 Bell Place\nNorth Robert, NJ 49636',
#  '098 Duran Light\nRileyshire, MS 20227',
#  '24213 Michael Neck\nSouth Peter, OK 77003',
#  '175 Mayo Rest Apt. 094\nJonesburgh, CA 03643',
#  '34716 Kristin Rapids Apt. 386\nSmithville, MN 85980',
#  '546 Jason Terrace\nJessicachester, MI 92559',
#  '2600 Melissa Plains\nRonaldburgh, FL 65979',
#  '72914 Campbell Avenue Suite 794\nPort Alex, OK 20389',
#  '058 Anthony Shore Suite 376\nCurtishaven, WI 32669',
#  '96376 Nathan Rue Apt. 728\nGriffithton, KY 61692',
#  '3531 Lisa Club\nNew Danielfort, CO 98212',
#  '0053 Rebecca Wells\nHuntermouth, AR 71885',
#  '98980 Lori Motorway Suite 656\nClarkland, VT 61706',
#  '89628 Tonya Light\nLoriburgh, HI 89949',
#  '837 Kelly Expressway Suite 778\nJacksonside, MT 98285',
#  '9811 Aguirre Key\nDorothyland, GA 72399',
#  '7936 Ann Pine Apt. 646\nColonstad, LA 70065',
#  '3370 Thomas Stream\nBakerland, RI 25912',
#  '08232 Marisa Port Apt. 080\nWest Gregory, MS 83637',
#  '688 Jason Hollow Suite 693\nJessicaborough, MA 05593',
#  '11650 Trevino Estates Suite 079\nAngelicamouth, KY 06685',
#  '48072 Rivera Bridge Suite 386\nNew Lisaland, NV 34121',
#  '4606 Toni Heights\nNew Mark, ME 10458',
#  '2612 Johnson Rue\nEast Timothyville, WY 74175',
#  'USS Chen\nFPO AA 10270',
#  '7567 Clayton Pine\nNorth Pamelabury, AL 01024',
#  '2741 Brittany Falls Apt. 193\nTerrencebury, KS 78234',
#  '055 Glover Mount Apt. 337\nDanielsborough, NV 42949',
#  '80462 Martin Ville Apt. 261\nLake Sydneymouth, NV 36477',
#  '890 Vicki Junction\nPatriciastad, CO 45847',
#  '901 Karen Heights\nRussellfort, AZ 78244',
#  'Unit 3624 PO BOX 4165\nDPO AE 96880',
#  '568 Matthew Turnpike Apt. 576\nMitchellborough, CA 86173',
#  '009 Brian Curve\nVillegashaven, VA 04688',
#  'USNS Fischer\nFPO AE 45323',
#  '00860 Lucas Island\nNorth Kyle, NM 07642',
#  '6010 Alvarado Corners\nAnneburgh, NM 49364',
#  '973 Bradley Burg Apt. 327\nHernandezshire, KS 16484',
#  '1531 Smith Meadow\nKrystalland, TX 81137',
#  '614 Jackson Court Apt. 205\nSouth Ashleyburgh, UT 55993',
#  '62535 Matthew Stream\nNorth Jonathon, RI 63820',
#  '0684 Jacob Summit Apt. 843\nJohnberg, ME 15133',
#  '73636 Leon Crescent\nEast Kevin, NC 80157',
#  '075 Todd Crossroad\nWest Jasonland, WY 55084',
#  'PSC 6153, PO BOX 8041\nAPO AE 45893',
#  '43125 Daniels Shores Apt. 765\nEast Charles, MA 72926',
#  '34799 Chavez Spurs\nNew Mariahland, ND 86671',
#  '848 Hickman Mills\nNicholasfurt, VT 87679',
#  'USS Glover\nFPO AP 69577',
#  '088 James Lakes\nSamanthaberg, AR 70563',
#  '875 Warren Land\nNorth Patrick, AK 87618',
#  '273 Tammy Drive Apt. 286\nLake Michelleport, UT 27222',
#  '00695 Lauren Crest\nNew Donaldfort, IA 15089',
#  '21552 Brandon Valley Apt. 711\nNorth Laurabury, MA 08841',
#  'USNV Medina\nFPO AA 82238',
#  '6313 Hayes Plain Suite 544\nGriffinton, IN 84770',
#  '840 Moore Summit Apt. 279\nBradyton, UT 68575',
#  '338 Steven Mount\nMarksville, AK 44723',
#  '33675 Snyder Ranch Apt. 729\nNew Michaelville, HI 31740',
#  '5531 Pearson Meadow\nNorth Michael, VT 88571',
#  '183 Erik Corners\nMarytown, NV 21963',
#  '47020 Hayes Brook\nWest Patricia, UT 96457',
#  '311 James Station Apt. 850\nPort Lauren, WI 52255',
#  '796 Walker Mall\nHessburgh, HI 39524',
#  '277 Rivera Inlet Apt. 080\nEast Anthonyville, VA 46530',
#  '82979 Robinson Trail\nPort Kristen, TN 32152',
#  '7947 Jeremiah Lights Suite 199\nStewartside, AL 20213',
#  '72382 Archer Point Apt. 237\nLake Laurenmouth, RI 43879',
#  '72944 Ashley Tunnel Apt. 592\nNorth Russell, MD 46214',
#  '93907 Evelyn Drive Apt. 796\nChambersview, MO 72305',
#  '863 Jackson Haven Apt. 590\nJuliaton, NM 30139',
#  '17635 Jonathan Knolls\nNew Andre, MD 87663',
#  '2469 Jordan Springs\nPort Bradleystad, NJ 96230',
#  '33229 Graves Flats Apt. 099\nNew Christopherland, NH 24920',
#  '576 James Manor\nSouth Barbaraborough, FL 39289',
#  '8347 Daniel Tunnel\nBriggsstad, IL 28101',
#  '86929 Vasquez Lake Suite 029\nSouth Elizabeth, OK 05666',
#  '0808 Garcia Loop\nNew Kelly, ME 22074',
#  '9584 Katherine Streets Suite 329\nWest Anthonyport, IL 46715',
#  '2782 Jacob Viaduct Apt. 851\nSouth Tracy, ND 24794',
#  '850 Jeffrey Parkway\nPort Laura, NC 68131',
#  '3537 Lance Fall Apt. 073\nNorth Michael, ND 00592',
#  '134 Turner Ville\nSmithborough, DE 92785',
#  '993 Smith Pine\nWest Catherinestad, WV 23443',
#  '604 Lisa Heights\nEast Jay, HI 82489',
#  '402 Thompson Center\nMichaeltown, NY 40664',
#  '53987 Wilson Street Suite 048\nWest Jadehaven, FL 82932',
#  'USCGC Lee\nFPO AA 38102',
#  'PSC 2769, PO BOX 6450\nAPO AA 72113',
#  '2883 Montgomery Tunnel\nNorth Kerri, DC 96960',
#  '4297 Brooks Causeway\nPort Annaton, DC 74227',
#  '22712 Lee Plain Suite 715\nCostaland, AR 04978',
#  'PSC 0165, PO BOX 6257\nAPO AE 82715',
#  '185 Jennifer Dam Apt. 277\nPort Rebekahchester, HI 05884',
#  '5423 Martin Inlet Suite 748\nHoganfurt, MT 83974',
#  '463 Cassidy Villages\nJohnfort, IN 75271',
#  '95913 York Drive\nBrownview, RI 13623',
#  '28086 Williams Cape\nWilliamstown, NE 66657',
#  '93312 Michael Port\nSouth Timothyville, CO 82892',
#  '7145 Rivera Islands Suite 470\nCopelandside, AK 94558',
#  '98407 Heidi Views\nNorth Luisberg, DC 84066',
#  '7302 Vicki Cliff Apt. 573\nKimberlyport, NE 84818',
#  '27753 Norris Burg\nPort Tommouth, OK 17173',
#  '1524 Underwood Neck\nNorth Juanton, IN 71759',
#  '1694 Lee Streets\nEast Kimberlyberg, SD 90567',
#  '0377 Reed Neck Suite 752\nRonaldbury, KS 80752',
#  '9102 Baker Mountain\nHornebury, OK 59407',
#  '9861 Hill Junctions\nWest Angelashire, WA 68720',
#  '1779 Allen Court Apt. 232\nWest Paulside, KS 24032',
#  '221 Matthew Mountain\nPhilipmouth, NE 21109',
#  '336 Robert Expressway Suite 049\nAndreafort, NH 63451',
#  '6699 Adam Extension\nRussellborough, VA 84984',
#  'Unit 2656 PO BOX 8066\nDPO AE 72691',
#  '41736 Nixon Station\nEast Paulaland, NJ 96656',
#  '2970 Turner Port\nAngelastad, WV 10037',
#  '55620 Adam Harbor Suite 261\nJohnsonland, KS 81445',
#  '9179 Mary Forks\nSouth Caseybury, AZ 93863',
#  '103 Bradley Fort\nRichardsonshire, FL 12523',
#  'PSC 7032, PO BOX 9702\nAPO AE 59310',
#  '868 Macias Islands\nLindaland, IA 55733',
#  '2495 Scott Keys Apt. 344\nEast Krystalburgh, SD 98772',
#  '5811 Santana Lodge\nDanielbury, TX 05072',
#  '0908 Justin Mountains Suite 469\nWest Anthony, CA 10238',
#  '691 Michael Lodge Apt. 455\nLake Markton, TN 58270',
#  '03528 Maria Road Suite 204\nChristybury, HI 31385',
#  '8107 Swanson Crossroad Apt. 601\nLake Nancyberg, IA 82877',
#  '19898 Daniel Freeway Apt. 286\nSheilaton, KS 29285',
#  '317 Silva Inlet Suite 027\nCastrofurt, ND 88450',
#  '223 Kathleen Vista\nWest Robertmouth, AL 07394',
#  '8725 Hurst Wall Suite 529\nWest Susan, IL 87362',
#  '429 Lauren Freeway\nAndersonview, KS 04491',
#  '6110 Stone Union Apt. 550\nLake Samuel, CT 49223',
#  '21354 Jason Crossing\nLake Annette, WA 69860',
#  '84682 Shaun Loaf\nLake Laurieville, OR 05972',
#  '7600 Matthew Stravenue Apt. 192\nJohnchester, IN 51531',
#  '8905 Janice Pine\nPort David, MD 53966',
#  'PSC 7371, PO BOX 7342\nAPO AE 81659',
#  '690 Flynn Brook\nGordonbury, HI 54285',
#  '73104 Smith Expressway Apt. 288\nEast Lisafort, IA 38293',
#  '48998 Zachary Crossing\nPort Joseph, UT 13653',
#  '985 Bolton Plaza Suite 079\nHughesfurt, DC 72683',
#  '19014 Jerry Forks Apt. 155\nHallchester, AK 29974',
#  '270 Angela Mountains\nJoshuachester, GA 76052',
#  '49791 Michael Port\nNorth Derrick, WV 09134',
#  '51091 Martin Cape Suite 471\nCummingsland, CA 28971',
#  '8720 Sosa Gardens\nEast Kathryntown, IA 31777',
#  '594 Edward Route Suite 041\nJeffreymouth, AZ 86613',
#  '79363 Ball Crossroad\nEast Jamesburgh, WI 59977',
#  '284 Brian Walks Suite 699\nSharonborough, AK 93518',
#  '2545 Clark Streets\nWest Ryanshire, GA 17748',
#  'Unit 7175 PO BOX 9760\nDPO AE 71911',
#  '11905 Brown Point\nLake Samantha, ND 43735',
#  'USCGC Brady\nFPO AA 11924',
#  '63305 Daniel Islands\nEast Ralphchester, KY 94427',
#  '7380 Hart Plains Apt. 774\nLake Katherineport, UT 88781',
#  '0271 Ricky Throughway\nWest Garyfort, NV 37079',
#  '035 Jenkins Island\nSouth Michaelland, RI 41838',
#  '639 Young Mews\nNew Chrismouth, NY 85067',
#  '323 Juarez Island\nAnthonymouth, UT 81458',
#  '3792 Mitchell Passage\nWagnerside, AK 48212',
#  '74325 Blankenship Island\nEast Sandrahaven, IA 22652',
#  '97653 Smith Fords\nLake Vanessa, MI 93813',
#  '946 Rebecca Glen\nLaurastad, MD 48491',
#  '1691 Morales Mews Apt. 581\nSouth Alan, WI 16809',
#  '0674 Shannon Hill Suite 455\nSimsshire, AL 51900',
#  '0426 Mendez Mills\nGonzalezfurt, UT 61201',
#  '72865 Carroll Road Apt. 082\nRickyburgh, LA 87935',
#  '0183 Lyons Unions Apt. 098\nKathryntown, RI 13704',
#  '1438 Anthony Knoll\nWilliammouth, NM 72613',
#  '5998 John Ford\nPort Wendy, IA 99380',
#  '51229 Goodwin Curve\nAshleyland, CT 68503',
#  '8090 Rios Cliffs\nRebeccafurt, WA 35338',
#  '763 Michael Wall Suite 996\nCatherinemouth, ME 46673',
#  '709 Melendez Way\nBellton, WV 74880',
#  '5562 Lewis Via Suite 707\nLewisport, UT 63759',
#  '4175 Robert Drive Apt. 355\nGonzalesview, ME 44493',
#  '8692 Barrett Inlet Apt. 849\nEvansberg, LA 98858',
#  '161 Cummings Valleys Apt. 406\nPort Austinport, AR 63728',
#  '33733 Mcknight Station Suite 524\nEast Katie, ND 56829',
#  '80045 Richard Hill Suite 774\nPort Paulfort, AL 83489',
#  'Unit 8023 PO BOX 5904\nDPO AA 28350',
#  '575 Lang Rue Suite 662\nPort Brandontown, MO 66813',
#  '6389 Jennifer Forest Apt. 920\nEast Ashley, HI 01387',
#  '79853 Laura Green\nBrandonfurt, WA 89156',
#  '755 Fields Station\nPort Cynthiaside, NE 47454',
#  'USS Wright\nFPO AE 26620',
#  '803 Hannah Mountains\nWest Ariel, LA 69951',
#  '6008 Antonio Cliff\nNorth Nathantown, VA 31779',
#  '845 Virginia Haven\nCarrburgh, MD 37908',
#  '983 Kimberly Points\nBanksview, OK 10949',
#  '281 Kelly Turnpike Apt. 286\nSouth Michelle, NH 67890',
#  '689 Allen Ranch\nNorth Saratown, SD 12542',
#  '964 John Rue\nEast Ashleyburgh, SC 91966',
#  '892 Hayes Tunnel Apt. 982\nJanetchester, NE 27832',
#  '5645 Jacqueline Pike Apt. 241\nRichardchester, VA 80868',
#  '14020 Jay Mountain\nAmandaside, SD 23702',
#  '4256 Emily Well\nJosephmouth, NE 15018',
#  '06659 Skinner Courts Suite 000\nLarryfort, AR 25879',
#  'PSC 4627, PO BOX 6732\nAPO AE 85793',
#  '25352 Keith Meadow Apt. 840\nOmarfurt, AK 86398',
#  '0618 Makayla Mount\nLake Craig, WV 31864',
#  '81939 Moore Estate Suite 600\nMartinborough, MA 57556',
#  '42551 Jeffery Parks Apt. 753\nJacksonmouth, NE 87551',
#  '276 Christine Mountains\nBrewerville, TX 83235',
#  'PSC 8169, PO BOX 9684\nAPO AA 40169',
#  '98671 Williams Harbors Suite 561\nNorth Brookemouth, KY 11292',
#  '645 James Ways Suite 077\nEast Kevinmouth, OH 30683',
#  '4146 Tina Rue\nBoothstad, PA 23363',
#  '52722 Ronald Points Apt. 744\nBarrettside, SD 79534',
#  '32857 Robert Groves Apt. 985\nLake Kenneth, TX 33455',
#  '19828 Rick Ville Apt. 931\nSouth Tiffany, CO 50300',
#  'Unit 0298 PO BOX 5649\nDPO AA 69270',
#  '700 Lynn Rapid Apt. 186\nSmithfurt, PA 46694',
#  '7063 Timothy Forest Suite 166\nNew Daniel, NE 84433',
#  '32931 Alvarez Pass\nEugenefort, MI 26424',
#  '650 Murphy Centers Apt. 112\nWest Christopherbury, DC 56752',
#  '4613 Hogan Expressway\nLake Hector, MS 81663',
#  '505 Phillips Manors Apt. 335\nEast Jessica, WY 82164',
#  '824 Wiley Mountains Apt. 042\nNorth Allison, WI 83211',
#  '7374 Sharon Mountains\nNew Georgebury, NY 41821',
#  '884 Kathryn Freeway\nMaddenland, PA 28521',
#  '8360 Charlene Turnpike\nBarrytown, RI 00957',
#  '60782 Nathaniel Knolls\nNew Robertshire, MO 80554',
#  '86539 Moore Ways Suite 966\nNew Laurashire, TN 18266',
#  '7552 Hayes Oval Apt. 242\nCastilloport, NC 87112',
#  '9261 Cook Estate Suite 874\nNew Alexisbury, WY 42022',
#  '0311 Laura Cliffs Suite 615\nWilliamsborough, NJ 04830',
#  '28445 Harris Avenue Apt. 020\nNorth Stacyshire, VA 77538',
#  '5915 Humphrey View Apt. 247\nPort Mary, MO 06637',
#  '3106 Davis Summit\nBrooksburgh, ND 25940',
#  '83454 Cheryl Springs Suite 193\nSouth Johnchester, HI 35059',
#  '37861 Aaron Haven Suite 190\nGarciashire, HI 25529',
#  '237 Martha Shoals\nEast Derrickstad, AZ 73677',
#  '88598 Cardenas Squares Apt. 647\nSouth Dalton, CT 49594',
#  '5267 Joyce Estate Apt. 714\nPort Sandra, DC 43615',
#  '1517 Teresa Loop Apt. 720\nPort Karlhaven, VA 62054',
#  '14145 Santos Vista\nPort Clinton, NM 90721',
#  '26843 Patrick Drives Suite 387\nTimothytown, ME 95000',
#  '453 Huerta Haven Suite 328\nChristopherburgh, NE 25349',
#  'PSC 9618, PO BOX 7063\nAPO AA 41769',
#  '730 Cochran Wall Suite 801\nYoungland, KS 48059',
#  '393 Kelly Harbor\nHillmouth, CT 29975',
#  '258 Emily Roads Suite 088\nLake Tiffanyburgh, NH 68613',
#  '43835 Young Villages Apt. 412\nRiveratown, IN 28333',
#  '91700 Miller Junctions Apt. 010\nRachelfurt, NC 75361',
#  '7106 Yvonne Wells\nBrookefurt, MI 18668',
#  'PSC 5091, PO BOX 5974\nAPO AE 68891',
#  '556 Julie Stream Apt. 601\nRichardberg, WY 33057',
#  '0548 Humphrey Vista\nHannahport, MS 34042',
#  'PSC 9557, PO BOX 5765\nAPO AE 02579',
#  '991 Kevin Villages Suite 278\nSouth Cameron, AZ 53028',
#  '722 Hicks Meadows\nLopezhaven, VT 98495',
#  '9564 Jeffery Estate\nWest Tylermouth, AZ 30171',
#  '1238 Kyle Knoll Suite 569\nPort Jasonville, CT 28458',
#  '73073 Williams Mills Suite 762\nWest Rebecca, RI 60858',
#  '72187 Mcgee Way\nTurnerhaven, AK 36794',
#  '7040 Sharon Lodge Apt. 377\nEast Brad, AK 75880',
#  'USS Maynard\nFPO AE 46069',
#  '2194 Cruz Brook\nHeatherport, NJ 21655',
#  'PSC 2879, PO BOX 7960\nAPO AP 82867',
#  '72927 Robinson Unions Apt. 618\nKyleborough, NC 90267',
#  '83771 Brooke Mountain Suite 706\nNorth Jacktown, OH 95736',
#  '62786 Maria Key\nLake Erikport, AL 55305',
#  '815 Deborah Extensions\nNorth Patricialand, PA 77684',
#  '3865 Gordon Greens Apt. 186\nJosephchester, NH 28659',
#  '40340 Eric Garden\nJosephfort, ID 22814',
#  'Unit 6976 PO BOX 8877\nDPO AE 62022',
#  '28539 Mcclure Trafficway Suite 755\nSouth Judy, ME 89788',
#  'Unit 6948 PO BOX 5191\nDPO AP 56531',
#  '46061 Barton Parkway Suite 057\nPort Petertown, CO 13164',
#  '1464 Chandler Ville\nWest Jeffreyburgh, HI 56593',
#  'Unit 5165 PO BOX 9475\nDPO AE 30473',
#  '885 Gloria Drive Apt. 390\nHayesstad, SC 38144',
#  '8031 Carrillo Mission Suite 786\nEast Williamberg, NV 81999',
#  '80176 John Points\nStevensport, NE 80405',
#  '920 Mcgee Gateway Suite 118\nPort Paula, SC 15985',
#  '4740 Michael Dale Suite 001\nReyeston, IN 73907',
#  '08291 Patricia Pass Suite 795\nNicoleview, NH 46259',
#  'Unit 8687 PO BOX 6795\nDPO AE 87960',
#  '626 Jackson Mews\nSanchezmouth, OK 04197',
#  '3021 Pineda Fort Apt. 892\nJasonburgh, NM 83207',
#  '21143 Lisa Mission Suite 809\nSamanthastad, CT 38781',
#  '72042 White Park\nKyleton, VA 92317',
#  '397 Owens Cliffs\nMichaeltown, CA 18123',
#  '76538 Meyer Square\nLake Claireport, MA 89479',
#  '34985 Lisa River Suite 995\nLake Kristentown, SC 49681',
#  '397 Wilson Ridges Suite 593\nZavalafort, CO 14218',
#  '4760 White Field\nHowardview, FL 61350',
#  '6639 Donald Shoals\nWest Tinatown, NE 36142',
#  '549 Francis Junctions Apt. 184\nBenjaminfurt, OK 38401',
#  '12640 Chase Stream Suite 521\nTiffanystad, TN 18040',
#  '8488 Natalie Points\nColleenport, VA 78615',
#  '08780 Kaitlyn Road\nSouth Cristina, MO 29821',
#  '744 Richard Cliff\nKarenbury, GA 44592',
#  'Unit 3523 PO BOX 3682\nDPO AA 88013',
#  '01828 Evans Mountain\nJenniferport, MN 45880',
#  '9373 Walker Village Suite 025\nSouth Janiceview, IN 50026',
#  '9506 Stewart Dale\nMaryshire, IA 28463',
#  '50342 Denise Radial\nSouth Melissa, CA 82927',
#  '582 Jonathan Divide Apt. 811\nAlexanderberg, IA 54531',
#  '925 Gray Brooks Suite 785\nDavidfort, MI 77373',
#  '564 Gallegos Ranch Suite 781\nJohnsonfort, WV 84038',
#  'USCGC Wells\nFPO AP 17268',
#  'PSC 7434, PO BOX 0558\nAPO AA 37402',
#  '182 John Rapids Suite 508\nCampbellborough, ID 45641',
#  'USCGC Vasquez\nFPO AE 08545',
#  '219 Harris Circles Apt. 764\nWest Ricardoport, OH 76299',
#  'USNS Yoder\nFPO AP 83316',
#  '08277 Lee Track Suite 304\nNorth Lisa, MS 33754',
#  '07241 Michael Hill\nEast Courtneyland, KS 11019']

# %% [markdown]
# # Handling PO BOX:
# + There are two types of PO BOX here:
#
# 1.) `Foreign US Military PO BOX`: which have string starting with (`PSC`) and contain:  (`APO,FPO`)
#     this corresponds to the `USPS` formatting of Foreign Military Postal Codes. Except the
#     position in the string here is inaccurate, but good enough for this exercise.
#
# 2.) The other PO BOX represent somewhat normal addresses.

# %%
# Take Everything After PO BOX, and stop at (\n)
po_box_with_num=re.compile(r'\b(:? PO BOX.*)+\b')

# Take Everything Before (PO BOX)
unit_num_pobox=re.compile(r'.+?(?=PO BOX)')

# Check if String Contains a Specific Word: print sentence
match_word=re.compile(r'\b(.*?PO BOX).+(\s\w.+)\b')


h=[]
# define_words='PO BOX'
for i in update_pobox: 
    if re.findall(match_word,i):
        h.append(re.findall(match_word,i))
#     h.append(re.search(define_words,i))
h[:2]
# update_pobox
# Out:
# [[('PSC 5627, PO BOX', '\nAPO AP 26601')],
#  [('Unit 7862 PO BOX', '\nDPO AA 94969')]]

# %% [markdown]
# # Find Strings with Apartment or Suite:

# %%
strg_apt_ste=[]

h=[]
for i in update_pobox: 
    if re.findall(re.compile(r'\b.+?(?=Apt|Suite)\b'),i):
        
        # everything before apt/suite appended but everything before apt/suite
        h.append(re.findall(re.compile(r'\b.+?(?=Apt|Suite)'),i))

        # append if string has apt/ste
        strg_apt_ste.append(i)

strg_apt_ste
# h
# Out:
# ['74187 Laurie Parkways Apt. 344\nLake Maria, MN 77577',
#  '4035 Perez Pass Apt. 421\nCalderonton, KS 89435',
#  '4637 Mary Inlet Apt. 200\nNew Robert, ME 48035',
#  '36411 Schwartz Shoals Suite 648\nEast Denise, NV 66145',
#  '811 Johnson Garden Suite 506\nYolandafort, RI 63534',
#  '976 Amanda Common Suite 647\nChristianchester, VT 25717',
#  '667 Andrea Divide Suite 768\nRubenbury, RI 76156',
#  '81186 Frank Ports Suite 654\nDebrafort, NE 47710',
#  '6325 Morse Pine Apt. 801\nRobertoburgh, MN 50010',
#  '5266 Hart Burgs Suite 937\nMoorebury, MO 58963',
#  '804 Hester Station Suite 574\nEast John, OH 02675',
#  '227 Melissa Fields Suite 756\nDavidborough, OH 69897',
#  '5702 Joshua Alley Suite 392\nBryanthaven, WY 33452',
#  '8309 Nichols Ford Apt. 391\nWilliambury, LA 67738',
#  '683 Nunez Parkway Suite 561\nOdonnellborough, NE 81031',
#  '8679 Young Stravenue Suite 338\nWestview, FL 29654',
#  '2694 Mcmillan Light Suite 626\nWangchester, CO 59661',
#  '082 Hood Passage Suite 334\nDawnmouth, SD 10335',
#  '36121 Travis Forks Apt. 236\nNew Paigechester, OR 96454',
#  '982 Avery Track Suite 934\nOconnellside, LA 30835',
#  '067 Adam Ville Suite 997\nWest Derrickborough, MI 35864',
#  '93956 Steven View Apt. 748\nWest Andrea, MS 47690',
#  '64316 Jennifer Fort Suite 264\nWest Nicolasfort, GA 97504',
#  '941 Jeremy Rest Apt. 486\nEast Allison, MD 48851',
#  '0051 Smith Throughway Apt. 996\nPort Donna, OH 15666',
#  '9851 Anderson Mills Suite 176\nEast Luke, LA 85007',
#  '8010 Ramirez Club Apt. 824\nSouth Johnhaven, MA 37605',
#  '8487 Lawrence Unions Apt. 567\nKellyberg, DE 81275',
#  '937 Amy Square Apt. 487\nCrystalshire, MS 78445',
#  '255 Camacho Street Apt. 674\nJimmyport, AL 29627',
#  '2257 Samantha Track Suite 699\nNorth Laurie, TN 68112',
#  '775 Frank Gateway Suite 399\nTapiamouth, FL 87450',
#  '632 Macdonald Locks Apt. 126\nSouth Joseph, NE 60938',
#  '80956 Julia Centers Apt. 765\nNew Lisa, TN 59234',
#  '4174 Corey Union Apt. 731\nBethanyview, AK 76453',
#  '23770 Murphy Ridges Suite 546\nEast Johnchester, UT 08945',
#  '501 Mitchell Flats Apt. 808\nKylebury, NM 77480',
#  '35345 Moore Plains Suite 101\nNew Lindaborough, ND 64886',
#  '8285 Vanessa Bypass Suite 779\nAnnetteberg, MI 73041',
#  '958 Moody Mount Apt. 787\nCrystalhaven, SD 08559',
#  '84025 Steele Neck Suite 578\nNew Jacob, NE 96300',
#  '741 Mario Extension Apt. 219\nJacksonborough, NV 46391',
#  '73318 Anderson Passage Apt. 976\nNew Ryan, VT 99408',
#  '353 Andrew Estates Apt. 598\nLewismouth, WY 37460',
#  '0260 Williams Glen Apt. 745\nEast Nicholas, CT 41968',
#  '02024 Elizabeth Fords Suite 697\nJohnstonchester, MD 69392',
#  '3541 Vega Prairie Apt. 067\nPort Leahmouth, DC 52797',
#  '25873 Gomez Key Suite 172\nLake Shellyton, IN 06390',
#  '42469 Lloyd Isle Suite 177\nNew Deborahfort, DE 26666',
#  '799 Pena Squares Suite 567\nEast Rodneyfort, CT 37704',
#  '303 Cindy Springs Suite 588\nFernandezland, WI 87118',
#  '477 Tammy Fall Suite 288\nNavarroton, VT 87014',
#  '7549 Salinas Meadow Apt. 147\nHortonstad, AL 30887',
#  '58902 Brenda Shoal Apt. 406\nLake Michael, AK 92604',
#  '15842 Kathy Island Suite 667\nGabriellaville, MD 55348',
#  '146 Baker Vista Suite 132\nLake Louisland, MO 98682',
#  '3694 Marcus Crest Suite 900\nStuartborough, MA 62279',
#  '96479 Perez Ville Suite 873\nWalkerberg, CA 97733',
#  '643 Clarke Manors Apt. 056\nEast Michaelland, MO 39259',
#  '3408 Sarah Stravenue Suite 528\nLake Jonathanshire, WV 99177',
#  '486 Taylor Ways Apt. 443\nBurchborough, AZ 11143',
#  '39204 Spencer Coves Apt. 857\nEast Brandon, IN 69031',
#  '917 David Locks Suite 044\nLake Jamieport, NE 60827',
#  '658 Drake Street Apt. 900\nSouth Frankshire, MS 19961',
#  '6079 Travis Trace Apt. 000\nWest Joshuaville, NC 98345',
#  '07725 Melinda Squares Apt. 377\nEast Amyfurt, OK 69416',
#  '546 Sawyer Summit Apt. 600\nLopezville, RI 71955',
#  '160 Brooke Wells Suite 758\nWilsonchester, ND 83410',
#  '2236 Benjamin Tunnel Apt. 190\nNew Courtneybury, SD 87573',
#  '39403 Edwards Ways Apt. 567\nMelindaberg, MD 44325',
#  '133 Antonio Estates Apt. 367\nFoxshire, NC 86707',
#  '9711 Timothy Neck Suite 727\nMadisonbury, OH 77458',
#  '95454 Kimberly Forest Apt. 522\nNguyenshire, MA 49938',
#  '192 Miller Harbors Apt. 666\nRickchester, OH 77901',
#  '3739 Jason Island Suite 484\nBrownshire, ME 32960',
#  '5185 John Forges Apt. 083\nHallton, UT 58189',
#  '7517 Powell Points Suite 892\nBestfurt, ID 49545',
#  '71018 Matthew Well Apt. 571\nMooreview, KS 38167',
#  '588 Carter Mission Suite 606\nSouth Christopher, OH 75072',
#  '5026 Duran Motorway Suite 434\nAndreabury, AL 12926',
#  '248 Sanders Fields Apt. 230\nMarytown, MA 26192',
#  '47113 David Lake Suite 697\nDavidside, TN 84401',
#  '6779 Marie Vista Apt. 772\nBarnesstad, ID 47897',
#  '41700 Smith Port Apt. 857\nPort Shawnville, CT 32722',
#  '803 Kathleen Lodge Apt. 756\nNew Charles, NV 12104',
#  '916 Meadows Route Apt. 748\nCollinsberg, MT 58671',
#  '6242 Gabriel Flat Apt. 868\nDeleonland, NH 79429',
#  '62595 Tyler Extensions Apt. 327\nRyantown, ME 10934',
#  '175 Mayo Rest Apt. 094\nJonesburgh, CA 03643',
#  '34716 Kristin Rapids Apt. 386\nSmithville, MN 85980',
#  '72914 Campbell Avenue Suite 794\nPort Alex, OK 20389',
#  '058 Anthony Shore Suite 376\nCurtishaven, WI 32669',
#  '96376 Nathan Rue Apt. 728\nGriffithton, KY 61692',
#  '98980 Lori Motorway Suite 656\nClarkland, VT 61706',
#  '837 Kelly Expressway Suite 778\nJacksonside, MT 98285',
#  '7936 Ann Pine Apt. 646\nColonstad, LA 70065',
#  '08232 Marisa Port Apt. 080\nWest Gregory, MS 83637',
#  '688 Jason Hollow Suite 693\nJessicaborough, MA 05593',
#  '11650 Trevino Estates Suite 079\nAngelicamouth, KY 06685',
#  '48072 Rivera Bridge Suite 386\nNew Lisaland, NV 34121',
#  '2741 Brittany Falls Apt. 193\nTerrencebury, KS 78234',
#  '055 Glover Mount Apt. 337\nDanielsborough, NV 42949',
#  '80462 Martin Ville Apt. 261\nLake Sydneymouth, NV 36477',
#  '568 Matthew Turnpike Apt. 576\nMitchellborough, CA 86173',
#  '973 Bradley Burg Apt. 327\nHernandezshire, KS 16484',
#  '614 Jackson Court Apt. 205\nSouth Ashleyburgh, UT 55993',
#  '0684 Jacob Summit Apt. 843\nJohnberg, ME 15133',
#  '43125 Daniels Shores Apt. 765\nEast Charles, MA 72926',
#  '273 Tammy Drive Apt. 286\nLake Michelleport, UT 27222',
#  '21552 Brandon Valley Apt. 711\nNorth Laurabury, MA 08841',
#  '6313 Hayes Plain Suite 544\nGriffinton, IN 84770',
#  '840 Moore Summit Apt. 279\nBradyton, UT 68575',
#  '33675 Snyder Ranch Apt. 729\nNew Michaelville, HI 31740',
#  '311 James Station Apt. 850\nPort Lauren, WI 52255',
#  '277 Rivera Inlet Apt. 080\nEast Anthonyville, VA 46530',
#  '7947 Jeremiah Lights Suite 199\nStewartside, AL 20213',
#  '72382 Archer Point Apt. 237\nLake Laurenmouth, RI 43879',
#  '72944 Ashley Tunnel Apt. 592\nNorth Russell, MD 46214',
#  '93907 Evelyn Drive Apt. 796\nChambersview, MO 72305',
#  '863 Jackson Haven Apt. 590\nJuliaton, NM 30139',
#  '33229 Graves Flats Apt. 099\nNew Christopherland, NH 24920',
#  '86929 Vasquez Lake Suite 029\nSouth Elizabeth, OK 05666',
#  '9584 Katherine Streets Suite 329\nWest Anthonyport, IL 46715',
#  '2782 Jacob Viaduct Apt. 851\nSouth Tracy, ND 24794',
#  '3537 Lance Fall Apt. 073\nNorth Michael, ND 00592',
#  '53987 Wilson Street Suite 048\nWest Jadehaven, FL 82932',
#  '22712 Lee Plain Suite 715\nCostaland, AR 04978',
#  '185 Jennifer Dam Apt. 277\nPort Rebekahchester, HI 05884',
#  '5423 Martin Inlet Suite 748\nHoganfurt, MT 83974',
#  '7145 Rivera Islands Suite 470\nCopelandside, AK 94558',
#  '7302 Vicki Cliff Apt. 573\nKimberlyport, NE 84818',
#  '0377 Reed Neck Suite 752\nRonaldbury, KS 80752',
#  '1779 Allen Court Apt. 232\nWest Paulside, KS 24032',
#  '336 Robert Expressway Suite 049\nAndreafort, NH 63451',
#  '55620 Adam Harbor Suite 261\nJohnsonland, KS 81445',
#  '2495 Scott Keys Apt. 344\nEast Krystalburgh, SD 98772',
#  '0908 Justin Mountains Suite 469\nWest Anthony, CA 10238',
#  '691 Michael Lodge Apt. 455\nLake Markton, TN 58270',
#  '03528 Maria Road Suite 204\nChristybury, HI 31385',
#  '8107 Swanson Crossroad Apt. 601\nLake Nancyberg, IA 82877',
#  '19898 Daniel Freeway Apt. 286\nSheilaton, KS 29285',
#  '317 Silva Inlet Suite 027\nCastrofurt, ND 88450',
#  '8725 Hurst Wall Suite 529\nWest Susan, IL 87362',
#  '6110 Stone Union Apt. 550\nLake Samuel, CT 49223',
#  '7600 Matthew Stravenue Apt. 192\nJohnchester, IN 51531',
#  '73104 Smith Expressway Apt. 288\nEast Lisafort, IA 38293',
#  '985 Bolton Plaza Suite 079\nHughesfurt, DC 72683',
#  '19014 Jerry Forks Apt. 155\nHallchester, AK 29974',
#  '51091 Martin Cape Suite 471\nCummingsland, CA 28971',
#  '594 Edward Route Suite 041\nJeffreymouth, AZ 86613',
#  '284 Brian Walks Suite 699\nSharonborough, AK 93518',
#  '7380 Hart Plains Apt. 774\nLake Katherineport, UT 88781',
#  '1691 Morales Mews Apt. 581\nSouth Alan, WI 16809',
#  '0674 Shannon Hill Suite 455\nSimsshire, AL 51900',
#  '72865 Carroll Road Apt. 082\nRickyburgh, LA 87935',
#  '0183 Lyons Unions Apt. 098\nKathryntown, RI 13704',
#  '763 Michael Wall Suite 996\nCatherinemouth, ME 46673',
#  '5562 Lewis Via Suite 707\nLewisport, UT 63759',
#  '4175 Robert Drive Apt. 355\nGonzalesview, ME 44493',
#  '8692 Barrett Inlet Apt. 849\nEvansberg, LA 98858',
#  '161 Cummings Valleys Apt. 406\nPort Austinport, AR 63728',
#  '33733 Mcknight Station Suite 524\nEast Katie, ND 56829',
#  '80045 Richard Hill Suite 774\nPort Paulfort, AL 83489',
#  '575 Lang Rue Suite 662\nPort Brandontown, MO 66813',
#  '6389 Jennifer Forest Apt. 920\nEast Ashley, HI 01387',
#  '281 Kelly Turnpike Apt. 286\nSouth Michelle, NH 67890',
#  '892 Hayes Tunnel Apt. 982\nJanetchester, NE 27832',
#  '5645 Jacqueline Pike Apt. 241\nRichardchester, VA 80868',
#  '06659 Skinner Courts Suite 000\nLarryfort, AR 25879',
#  '25352 Keith Meadow Apt. 840\nOmarfurt, AK 86398',
#  '81939 Moore Estate Suite 600\nMartinborough, MA 57556',
#  '42551 Jeffery Parks Apt. 753\nJacksonmouth, NE 87551',
#  '98671 Williams Harbors Suite 561\nNorth Brookemouth, KY 11292',
#  '645 James Ways Suite 077\nEast Kevinmouth, OH 30683',
#  '52722 Ronald Points Apt. 744\nBarrettside, SD 79534',
#  '32857 Robert Groves Apt. 985\nLake Kenneth, TX 33455',
#  '19828 Rick Ville Apt. 931\nSouth Tiffany, CO 50300',
#  '700 Lynn Rapid Apt. 186\nSmithfurt, PA 46694',
#  '7063 Timothy Forest Suite 166\nNew Daniel, NE 84433',
#  '650 Murphy Centers Apt. 112\nWest Christopherbury, DC 56752',
#  '505 Phillips Manors Apt. 335\nEast Jessica, WY 82164',
#  '824 Wiley Mountains Apt. 042\nNorth Allison, WI 83211',
#  '86539 Moore Ways Suite 966\nNew Laurashire, TN 18266',
#  '7552 Hayes Oval Apt. 242\nCastilloport, NC 87112',
#  '9261 Cook Estate Suite 874\nNew Alexisbury, WY 42022',
#  '0311 Laura Cliffs Suite 615\nWilliamsborough, NJ 04830',
#  '28445 Harris Avenue Apt. 020\nNorth Stacyshire, VA 77538',
#  '5915 Humphrey View Apt. 247\nPort Mary, MO 06637',
#  '83454 Cheryl Springs Suite 193\nSouth Johnchester, HI 35059',
#  '37861 Aaron Haven Suite 190\nGarciashire, HI 25529',
#  '88598 Cardenas Squares Apt. 647\nSouth Dalton, CT 49594',
#  '5267 Joyce Estate Apt. 714\nPort Sandra, DC 43615',
#  '1517 Teresa Loop Apt. 720\nPort Karlhaven, VA 62054',
#  '26843 Patrick Drives Suite 387\nTimothytown, ME 95000',
#  '453 Huerta Haven Suite 328\nChristopherburgh, NE 25349',
#  '730 Cochran Wall Suite 801\nYoungland, KS 48059',
#  '258 Emily Roads Suite 088\nLake Tiffanyburgh, NH 68613',
#  '43835 Young Villages Apt. 412\nRiveratown, IN 28333',
#  '91700 Miller Junctions Apt. 010\nRachelfurt, NC 75361',
#  '556 Julie Stream Apt. 601\nRichardberg, WY 33057',
#  '991 Kevin Villages Suite 278\nSouth Cameron, AZ 53028',
#  '1238 Kyle Knoll Suite 569\nPort Jasonville, CT 28458',
#  '73073 Williams Mills Suite 762\nWest Rebecca, RI 60858',
#  '7040 Sharon Lodge Apt. 377\nEast Brad, AK 75880',
#  '72927 Robinson Unions Apt. 618\nKyleborough, NC 90267',
#  '83771 Brooke Mountain Suite 706\nNorth Jacktown, OH 95736',
#  '3865 Gordon Greens Apt. 186\nJosephchester, NH 28659',
#  '28539 Mcclure Trafficway Suite 755\nSouth Judy, ME 89788',
#  '46061 Barton Parkway Suite 057\nPort Petertown, CO 13164',
#  '885 Gloria Drive Apt. 390\nHayesstad, SC 38144',
#  '8031 Carrillo Mission Suite 786\nEast Williamberg, NV 81999',
#  '920 Mcgee Gateway Suite 118\nPort Paula, SC 15985',
#  '4740 Michael Dale Suite 001\nReyeston, IN 73907',
#  '08291 Patricia Pass Suite 795\nNicoleview, NH 46259',
#  '3021 Pineda Fort Apt. 892\nJasonburgh, NM 83207',
#  '21143 Lisa Mission Suite 809\nSamanthastad, CT 38781',
#  '34985 Lisa River Suite 995\nLake Kristentown, SC 49681',
#  '397 Wilson Ridges Suite 593\nZavalafort, CO 14218',
#  '549 Francis Junctions Apt. 184\nBenjaminfurt, OK 38401',
#  '12640 Chase Stream Suite 521\nTiffanystad, TN 18040',
#  '9373 Walker Village Suite 025\nSouth Janiceview, IN 50026',
#  '582 Jonathan Divide Apt. 811\nAlexanderberg, IA 54531',
#  '925 Gray Brooks Suite 785\nDavidfort, MI 77373',
#  '564 Gallegos Ranch Suite 781\nJohnsonfort, WV 84038',
#  '182 John Rapids Suite 508\nCampbellborough, ID 45641',
#  '219 Harris Circles Apt. 764\nWest Ricardoport, OH 76299',
#  '08277 Lee Track Suite 304\nNorth Lisa, MS 33754']

# %% [markdown]
# # Extracting everything that is NOT PO BOX:

# %%
no_pobox=[]

match_word_pobox=re.compile(r'\b(.*?PO BOX).+(\s\w.+)\b')
for i in update_pobox: 
    if re.findall(match_word_pobox,i):
        pass
    else:
        no_pobox.append(i)

no_pobox
# Out:
# ['74187 Laurie Parkways Apt. 344\nLake Maria, MN 77577',
#  '4035 Perez Pass Apt. 421\nCalderonton, KS 89435',
#  '0086 Cohen Trafficway\nNorth Joseph, WV 50669',
#  '4637 Mary Inlet Apt. 200\nNew Robert, ME 48035',
#  '36411 Schwartz Shoals Suite 648\nEast Denise, NV 66145',
#  '811 Johnson Garden Suite 506\nYolandafort, RI 63534',
#  '976 Amanda Common Suite 647\nChristianchester, VT 25717',
#  'USNV Maddox\nFPO AA 77402',
#  '0259 Douglas Gardens\nNew Aliciaberg, NM 73609',
#  '372 Wilson Common\nLake Latasha, MA 90202',
#  '667 Andrea Divide Suite 768\nRubenbury, RI 76156',
#  '81186 Frank Ports Suite 654\nDebrafort, NE 47710',
#  '6325 Morse Pine Apt. 801\nRobertoburgh, MN 50010',
#  '5266 Hart Burgs Suite 937\nMoorebury, MO 58963',
#  '804 Hester Station Suite 574\nEast John, OH 02675',
#  '227 Melissa Fields Suite 756\nDavidborough, OH 69897',
#  '906 Karen Loaf\nLake Jason, NY 87552',
#  '5517 Teresa Drive\nEast Mason, TN 57993',
#  '5702 Joshua Alley Suite 392\nBryanthaven, WY 33452',
#  '499 Michael Shores\nSouth Brenda, AR 44326',
#  '8309 Nichols Ford Apt. 391\nWilliambury, LA 67738',
#  '683 Nunez Parkway Suite 561\nOdonnellborough, NE 81031',
#  '8679 Young Stravenue Suite 338\nWestview, FL 29654',
#  '89049 Jessica Road\nWest Meagan, OH 88771',
#  '2694 Mcmillan Light Suite 626\nWangchester, CO 59661',
#  '63991 Lee Station\nClarencetown, DC 37301',
#  '0384 Carrie Mills\nChanburgh, MT 24541',
#  '239 Nichole Station\nEast Cameron, MS 80908',
#  '082 Hood Passage Suite 334\nDawnmouth, SD 10335',
#  '36121 Travis Forks Apt. 236\nNew Paigechester, OR 96454',
#  '927 Donald Turnpike\nLake Edwardmouth, CT 14757',
#  '982 Avery Track Suite 934\nOconnellside, LA 30835',
#  '1283 Jonathan Springs\nVictoriaport, WV 88955',
#  '007 Carla Parkway\nPorterbury, NJ 83519',
#  '2465 Gerald Mews\nPort Michael, NM 77520',
#  '067 Adam Ville Suite 997\nWest Derrickborough, MI 35864',
#  '93956 Steven View Apt. 748\nWest Andrea, MS 47690',
#  '6071 Zachary Mall\nNorth Grace, FL 15686',
#  '8106 Contreras Landing\nEast Stephanieshire, AK 90567',
#  '64316 Jennifer Fort Suite 264\nWest Nicolasfort, GA 97504',
#  '941 Jeremy Rest Apt. 486\nEast Allison, MD 48851',
#  '778 Steve Key\nLake Chad, KS 81740',
#  '0051 Smith Throughway Apt. 996\nPort Donna, OH 15666',
#  '9851 Anderson Mills Suite 176\nEast Luke, LA 85007',
#  '8010 Ramirez Club Apt. 824\nSouth Johnhaven, MA 37605',
#  '8487 Lawrence Unions Apt. 567\nKellyberg, DE 81275',
#  '41419 Aguilar Throughway\nEast Jeffreyborough, LA 42663',
#  '937 Amy Square Apt. 487\nCrystalshire, MS 78445',
#  '823 Hamilton Forges\nLake Dennis, NM 86895',
#  '6079 Mahoney Highway\nNew Gary, OK 84354',
#  '84788 Campos Pike\nFreemanstad, WV 61997',
#  '450 Brian Passage\nNorth Jamesville, SC 15291',
#  '92345 Terrence Green\nLake Cynthia, WI 72609',
#  '9526 Keith Mountains\nJulieborough, NE 74563',
#  '315 Brandon Harbors\nEast Benjaminland, MI 57476',
#  '3784 Chen Estate\nEast Carmen, HI 93102',
#  '255 Camacho Street Apt. 674\nJimmyport, AL 29627',
#  '2257 Samantha Track Suite 699\nNorth Laurie, TN 68112',
#  '48146 Martin Shore\nChristopherland, TX 75493',
#  '9301 Gregory Center\nHooperbury, MS 64382',
#  '7752 Garner Bypass\nLake Cristianview, VT 47099',
#  '775 Frank Gateway Suite 399\nTapiamouth, FL 87450',
#  '632 Macdonald Locks Apt. 126\nSouth Joseph, NE 60938',
#  '24765 Gregory Haven\nLeemouth, NJ 94248',
#  '80956 Julia Centers Apt. 765\nNew Lisa, TN 59234',
#  '78599 Scott Centers\nLake Maurice, MN 38430',
#  '886 Hall Streets\nEast Michael, MA 32110',
#  '7104 Jackson Throughway\nPort Miguelburgh, MO 58453',
#  '8223 Brian Summit\nWebbburgh, ME 43060',
#  '197 Rose Cape\nPort Meganhaven, DE 44288',
#  '4174 Corey Union Apt. 731\nBethanyview, AK 76453',
#  '23770 Murphy Ridges Suite 546\nEast Johnchester, UT 08945',
#  '501 Mitchell Flats Apt. 808\nKylebury, NM 77480',
#  '35345 Moore Plains Suite 101\nNew Lindaborough, ND 64886',
#  '8285 Vanessa Bypass Suite 779\nAnnetteberg, MI 73041',
#  '99739 Ashley Rue\nAlvaradochester, MD 59304',
#  '34554 Hoffman Street\nLisatown, AK 72249',
#  '958 Moody Mount Apt. 787\nCrystalhaven, SD 08559',
#  '84025 Steele Neck Suite 578\nNew Jacob, NE 96300',
#  '53853 Torres Ports\nNew Bethberg, RI 53889',
#  'USNV Lewis\nFPO AA 92743',
#  '741 Mario Extension Apt. 219\nJacksonborough, NV 46391',
#  '284 Meghan Way\nWagnerbury, CO 56330',
#  '18877 Perez Burg\nDiazberg, MN 37514',
#  '73318 Anderson Passage Apt. 976\nNew Ryan, VT 99408',
#  '353 Andrew Estates Apt. 598\nLewismouth, WY 37460',
#  '602 Scott Flats\nWest Brian, MS 19093',
#  '0260 Williams Glen Apt. 745\nEast Nicholas, CT 41968',
#  '02024 Elizabeth Fords Suite 697\nJohnstonchester, MD 69392',
#  '8901 Jennifer Fields\nJosephbury, SC 15238',
#  '3541 Vega Prairie Apt. 067\nPort Leahmouth, DC 52797',
#  '25873 Gomez Key Suite 172\nLake Shellyton, IN 06390',
#  '567 April Manor\nRiveraville, NE 51210',
#  '21794 Brandi Spur\nNorth Kristin, NY 07562',
#  '43833 Smith Pass\nNew Scott, CA 91552',
#  '42469 Lloyd Isle Suite 177\nNew Deborahfort, DE 26666',
#  '799 Pena Squares Suite 567\nEast Rodneyfort, CT 37704',
#  '303 Cindy Springs Suite 588\nFernandezland, WI 87118',
#  '477 Tammy Fall Suite 288\nNavarroton, VT 87014',
#  '305 Gray Inlet\nStephanieton, GA 64285',
#  '134 Wagner Street\nWilliamsbury, IA 75602',
#  '476 Potter Roads\nDeckerhaven, MD 92255',
#  '910 Green Run\nHollowaybury, RI 55379',
#  '7549 Salinas Meadow Apt. 147\nHortonstad, AL 30887',
#  '869 Patrick Lock\nStrongmouth, ID 67242',
#  '58902 Brenda Shoal Apt. 406\nLake Michael, AK 92604',
#  '1529 Moore Lock\nEast Jessicaborough, IL 29749',
#  '5671 Brent Lake\nJamesbury, DE 63032',
#  '15842 Kathy Island Suite 667\nGabriellaville, MD 55348',
#  '146 Baker Vista Suite 132\nLake Louisland, MO 98682',
#  '78159 Andrews Plaza\nCoxberg, TX 04469',
#  'USNV Wu\nFPO AE 47182',
#  '3694 Marcus Crest Suite 900\nStuartborough, MA 62279',
#  '96479 Perez Ville Suite 873\nWalkerberg, CA 97733',
#  '643 Clarke Manors Apt. 056\nEast Michaelland, MO 39259',
#  '4923 Toni Lane\nKyleport, KS 09837',
#  '3408 Sarah Stravenue Suite 528\nLake Jonathanshire, WV 99177',
#  '486 Taylor Ways Apt. 443\nBurchborough, AZ 11143',
#  '39204 Spencer Coves Apt. 857\nEast Brandon, IN 69031',
#  '02806 Noah Mountains\nJasonburgh, MO 27388',
#  '62568 Rush Point\nNew Cameron, GA 20222',
#  '0619 Steven Crest\nVictorfort, WA 58860',
#  '710 Felicia Dam\nHartmanport, SD 37384',
#  '9717 Kelly Ports\nAlisonside, NH 95813',
#  '917 David Locks Suite 044\nLake Jamieport, NE 60827',
#  '658 Drake Street Apt. 900\nSouth Frankshire, MS 19961',
#  '6079 Travis Trace Apt. 000\nWest Joshuaville, NC 98345',
#  '07725 Melinda Squares Apt. 377\nEast Amyfurt, OK 69416',
#  '546 Sawyer Summit Apt. 600\nLopezville, RI 71955',
#  '52857 Lewis Extension\nKevinton, AR 34667',
#  '160 Brooke Wells Suite 758\nWilsonchester, ND 83410',
#  '57891 Foley Burgs\nNorth Ashley, AZ 63751',
#  '2898 Justin Mall\nPort Cherylhaven, TX 58787',
#  '8022 Bray Harbors\nHesterfurt, TN 30095',
#  '2236 Benjamin Tunnel Apt. 190\nNew Courtneybury, SD 87573',
#  '889 Michael Park\nNorrismouth, CT 64653',
#  '8099 Fuentes Oval\nGarciaborough, KY 50446',
#  '39403 Edwards Ways Apt. 567\nMelindaberg, MD 44325',
#  '133 Antonio Estates Apt. 367\nFoxshire, NC 86707',
#  '719 Sara Villages\nJustinmouth, NH 36813',
#  '9711 Timothy Neck Suite 727\nMadisonbury, OH 77458',
#  '995 Morgan Lodge\nAndersonview, GA 94018',
#  '95454 Kimberly Forest Apt. 522\nNguyenshire, MA 49938',
#  '192 Miller Harbors Apt. 666\nRickchester, OH 77901',
#  '3739 Jason Island Suite 484\nBrownshire, ME 32960',
#  '5185 John Forges Apt. 083\nHallton, UT 58189',
#  '887 Hayes Divide\nSouth Kellyport, KY 03217',
#  '9005 Michael Union\nRhondaton, CA 73750',
#  '2711 Jasmine Inlet\nPort Kayla, WI 17939',
#  '7517 Powell Points Suite 892\nBestfurt, ID 49545',
#  '82143 Pittman Lights\nWest Paul, CO 92690',
#  '606 Kathleen Square\nEast Shaneberg, MN 37391',
#  '0761 George Garden\nRojasstad, WA 62820',
#  '71018 Matthew Well Apt. 571\nMooreview, KS 38167',
#  '4093 Michael Plains\nWest Christine, WA 89000',
#  'USNV Sloan\nFPO AP 06977',
#  '3750 Sanders Garden\nEast Amanda, WY 62208',
#  '4056 Molly Falls\nWest Brianmouth, PA 46280',
#  '6378 Pearson Lakes\nRobertschester, OR 66112',
#  '31366 Lopez Circles\nChristopherview, NH 90065',
#  '95168 Katherine Gardens\nMooreland, NM 10210',
#  '588 Carter Mission Suite 606\nSouth Christopher, OH 75072',
#  '7293 Jennifer Drives\nJosephborough, AZ 53348',
#  '5026 Duran Motorway Suite 434\nAndreabury, AL 12926',
#  '934 Foster Creek\nNorth Roberttown, ME 62705',
#  '72952 Wheeler Forks\nTurnermouth, NM 17467',
#  '248 Sanders Fields Apt. 230\nMarytown, MA 26192',
#  '03317 Fuller Falls\nLake Christopher, MD 60015',
#  '4872 Guzman Prairie\nPort Joseph, DC 91142',
#  '456 Reyes Path\nSouth Crystaltown, NC 27087',
#  '47113 David Lake Suite 697\nDavidside, TN 84401',
#  '6779 Marie Vista Apt. 772\nBarnesstad, ID 47897',
#  '591 Paula Trace\nPort Mariahaven, NM 47716',
#  '8704 Williams Bridge\nSellersport, IL 14704',
#  '41700 Smith Port Apt. 857\nPort Shawnville, CT 32722',
#  '803 Kathleen Lodge Apt. 756\nNew Charles, NV 12104',
#  '916 Meadows Route Apt. 748\nCollinsberg, MT 58671',
#  '6242 Gabriel Flat Apt. 868\nDeleonland, NH 79429',
#  '62595 Tyler Extensions Apt. 327\nRyantown, ME 10934',
#  '69958 Bell Place\nNorth Robert, NJ 49636',
#  '098 Duran Light\nRileyshire, MS 20227',
#  '24213 Michael Neck\nSouth Peter, OK 77003',
#  '175 Mayo Rest Apt. 094\nJonesburgh, CA 03643',
#  '34716 Kristin Rapids Apt. 386\nSmithville, MN 85980',
#  '546 Jason Terrace\nJessicachester, MI 92559',
#  '2600 Melissa Plains\nRonaldburgh, FL 65979',
#  '72914 Campbell Avenue Suite 794\nPort Alex, OK 20389',
#  '058 Anthony Shore Suite 376\nCurtishaven, WI 32669',
#  '96376 Nathan Rue Apt. 728\nGriffithton, KY 61692',
#  '3531 Lisa Club\nNew Danielfort, CO 98212',
#  '0053 Rebecca Wells\nHuntermouth, AR 71885',
#  '98980 Lori Motorway Suite 656\nClarkland, VT 61706',
#  '89628 Tonya Light\nLoriburgh, HI 89949',
#  '837 Kelly Expressway Suite 778\nJacksonside, MT 98285',
#  '9811 Aguirre Key\nDorothyland, GA 72399',
#  '7936 Ann Pine Apt. 646\nColonstad, LA 70065',
#  '3370 Thomas Stream\nBakerland, RI 25912',
#  '08232 Marisa Port Apt. 080\nWest Gregory, MS 83637',
#  '688 Jason Hollow Suite 693\nJessicaborough, MA 05593',
#  '11650 Trevino Estates Suite 079\nAngelicamouth, KY 06685',
#  '48072 Rivera Bridge Suite 386\nNew Lisaland, NV 34121',
#  '4606 Toni Heights\nNew Mark, ME 10458',
#  '2612 Johnson Rue\nEast Timothyville, WY 74175',
#  'USS Chen\nFPO AA 10270',
#  '7567 Clayton Pine\nNorth Pamelabury, AL 01024',
#  '2741 Brittany Falls Apt. 193\nTerrencebury, KS 78234',
#  '055 Glover Mount Apt. 337\nDanielsborough, NV 42949',
#  '80462 Martin Ville Apt. 261\nLake Sydneymouth, NV 36477',
#  '890 Vicki Junction\nPatriciastad, CO 45847',
#  '901 Karen Heights\nRussellfort, AZ 78244',
#  '568 Matthew Turnpike Apt. 576\nMitchellborough, CA 86173',
#  '009 Brian Curve\nVillegashaven, VA 04688',
#  'USNS Fischer\nFPO AE 45323',
#  '00860 Lucas Island\nNorth Kyle, NM 07642',
#  '6010 Alvarado Corners\nAnneburgh, NM 49364',
#  '973 Bradley Burg Apt. 327\nHernandezshire, KS 16484',
#  '1531 Smith Meadow\nKrystalland, TX 81137',
#  '614 Jackson Court Apt. 205\nSouth Ashleyburgh, UT 55993',
#  '62535 Matthew Stream\nNorth Jonathon, RI 63820',
#  '0684 Jacob Summit Apt. 843\nJohnberg, ME 15133',
#  '73636 Leon Crescent\nEast Kevin, NC 80157',
#  '075 Todd Crossroad\nWest Jasonland, WY 55084',
#  '43125 Daniels Shores Apt. 765\nEast Charles, MA 72926',
#  '34799 Chavez Spurs\nNew Mariahland, ND 86671',
#  '848 Hickman Mills\nNicholasfurt, VT 87679',
#  'USS Glover\nFPO AP 69577',
#  '088 James Lakes\nSamanthaberg, AR 70563',
#  '875 Warren Land\nNorth Patrick, AK 87618',
#  '273 Tammy Drive Apt. 286\nLake Michelleport, UT 27222',
#  '00695 Lauren Crest\nNew Donaldfort, IA 15089',
#  '21552 Brandon Valley Apt. 711\nNorth Laurabury, MA 08841',
#  'USNV Medina\nFPO AA 82238',
#  '6313 Hayes Plain Suite 544\nGriffinton, IN 84770',
#  '840 Moore Summit Apt. 279\nBradyton, UT 68575',
#  '338 Steven Mount\nMarksville, AK 44723',
#  '33675 Snyder Ranch Apt. 729\nNew Michaelville, HI 31740',
#  '5531 Pearson Meadow\nNorth Michael, VT 88571',
#  '183 Erik Corners\nMarytown, NV 21963',
#  '47020 Hayes Brook\nWest Patricia, UT 96457',
#  '311 James Station Apt. 850\nPort Lauren, WI 52255',
#  '796 Walker Mall\nHessburgh, HI 39524',
#  '277 Rivera Inlet Apt. 080\nEast Anthonyville, VA 46530',
#  '82979 Robinson Trail\nPort Kristen, TN 32152',
#  '7947 Jeremiah Lights Suite 199\nStewartside, AL 20213',
#  '72382 Archer Point Apt. 237\nLake Laurenmouth, RI 43879',
#  '72944 Ashley Tunnel Apt. 592\nNorth Russell, MD 46214',
#  '93907 Evelyn Drive Apt. 796\nChambersview, MO 72305',
#  '863 Jackson Haven Apt. 590\nJuliaton, NM 30139',
#  '17635 Jonathan Knolls\nNew Andre, MD 87663',
#  '2469 Jordan Springs\nPort Bradleystad, NJ 96230',
#  '33229 Graves Flats Apt. 099\nNew Christopherland, NH 24920',
#  '576 James Manor\nSouth Barbaraborough, FL 39289',
#  '8347 Daniel Tunnel\nBriggsstad, IL 28101',
#  '86929 Vasquez Lake Suite 029\nSouth Elizabeth, OK 05666',
#  '0808 Garcia Loop\nNew Kelly, ME 22074',
#  '9584 Katherine Streets Suite 329\nWest Anthonyport, IL 46715',
#  '2782 Jacob Viaduct Apt. 851\nSouth Tracy, ND 24794',
#  '850 Jeffrey Parkway\nPort Laura, NC 68131',
#  '3537 Lance Fall Apt. 073\nNorth Michael, ND 00592',
#  '134 Turner Ville\nSmithborough, DE 92785',
#  '993 Smith Pine\nWest Catherinestad, WV 23443',
#  '604 Lisa Heights\nEast Jay, HI 82489',
#  '402 Thompson Center\nMichaeltown, NY 40664',
#  '53987 Wilson Street Suite 048\nWest Jadehaven, FL 82932',
#  'USCGC Lee\nFPO AA 38102',
#  '2883 Montgomery Tunnel\nNorth Kerri, DC 96960',
#  '4297 Brooks Causeway\nPort Annaton, DC 74227',
#  '22712 Lee Plain Suite 715\nCostaland, AR 04978',
#  '185 Jennifer Dam Apt. 277\nPort Rebekahchester, HI 05884',
#  '5423 Martin Inlet Suite 748\nHoganfurt, MT 83974',
#  '463 Cassidy Villages\nJohnfort, IN 75271',
#  '95913 York Drive\nBrownview, RI 13623',
#  '28086 Williams Cape\nWilliamstown, NE 66657',
#  '93312 Michael Port\nSouth Timothyville, CO 82892',
#  '7145 Rivera Islands Suite 470\nCopelandside, AK 94558',
#  '98407 Heidi Views\nNorth Luisberg, DC 84066',
#  '7302 Vicki Cliff Apt. 573\nKimberlyport, NE 84818',
#  '27753 Norris Burg\nPort Tommouth, OK 17173',
#  '1524 Underwood Neck\nNorth Juanton, IN 71759',
#  '1694 Lee Streets\nEast Kimberlyberg, SD 90567',
#  '0377 Reed Neck Suite 752\nRonaldbury, KS 80752',
#  '9102 Baker Mountain\nHornebury, OK 59407',
#  '9861 Hill Junctions\nWest Angelashire, WA 68720',
#  '1779 Allen Court Apt. 232\nWest Paulside, KS 24032',
#  '221 Matthew Mountain\nPhilipmouth, NE 21109',
#  '336 Robert Expressway Suite 049\nAndreafort, NH 63451',
#  '6699 Adam Extension\nRussellborough, VA 84984',
#  '41736 Nixon Station\nEast Paulaland, NJ 96656',
#  '2970 Turner Port\nAngelastad, WV 10037',
#  '55620 Adam Harbor Suite 261\nJohnsonland, KS 81445',
#  '9179 Mary Forks\nSouth Caseybury, AZ 93863',
#  '103 Bradley Fort\nRichardsonshire, FL 12523',
#  '868 Macias Islands\nLindaland, IA 55733',
#  '2495 Scott Keys Apt. 344\nEast Krystalburgh, SD 98772',
#  '5811 Santana Lodge\nDanielbury, TX 05072',
#  '0908 Justin Mountains Suite 469\nWest Anthony, CA 10238',
#  '691 Michael Lodge Apt. 455\nLake Markton, TN 58270',
#  '03528 Maria Road Suite 204\nChristybury, HI 31385',
#  '8107 Swanson Crossroad Apt. 601\nLake Nancyberg, IA 82877',
#  '19898 Daniel Freeway Apt. 286\nSheilaton, KS 29285',
#  '317 Silva Inlet Suite 027\nCastrofurt, ND 88450',
#  '223 Kathleen Vista\nWest Robertmouth, AL 07394',
#  '8725 Hurst Wall Suite 529\nWest Susan, IL 87362',
#  '429 Lauren Freeway\nAndersonview, KS 04491',
#  '6110 Stone Union Apt. 550\nLake Samuel, CT 49223',
#  '21354 Jason Crossing\nLake Annette, WA 69860',
#  '84682 Shaun Loaf\nLake Laurieville, OR 05972',
#  '7600 Matthew Stravenue Apt. 192\nJohnchester, IN 51531',
#  '8905 Janice Pine\nPort David, MD 53966',
#  '690 Flynn Brook\nGordonbury, HI 54285',
#  '73104 Smith Expressway Apt. 288\nEast Lisafort, IA 38293',
#  '48998 Zachary Crossing\nPort Joseph, UT 13653',
#  '985 Bolton Plaza Suite 079\nHughesfurt, DC 72683',
#  '19014 Jerry Forks Apt. 155\nHallchester, AK 29974',
#  '270 Angela Mountains\nJoshuachester, GA 76052',
#  '49791 Michael Port\nNorth Derrick, WV 09134',
#  '51091 Martin Cape Suite 471\nCummingsland, CA 28971',
#  '8720 Sosa Gardens\nEast Kathryntown, IA 31777',
#  '594 Edward Route Suite 041\nJeffreymouth, AZ 86613',
#  '79363 Ball Crossroad\nEast Jamesburgh, WI 59977',
#  '284 Brian Walks Suite 699\nSharonborough, AK 93518',
#  '2545 Clark Streets\nWest Ryanshire, GA 17748',
#  '11905 Brown Point\nLake Samantha, ND 43735',
#  'USCGC Brady\nFPO AA 11924',
#  '63305 Daniel Islands\nEast Ralphchester, KY 94427',
#  '7380 Hart Plains Apt. 774\nLake Katherineport, UT 88781',
#  '0271 Ricky Throughway\nWest Garyfort, NV 37079',
#  '035 Jenkins Island\nSouth Michaelland, RI 41838',
#  '639 Young Mews\nNew Chrismouth, NY 85067',
#  '323 Juarez Island\nAnthonymouth, UT 81458',
#  '3792 Mitchell Passage\nWagnerside, AK 48212',
#  '74325 Blankenship Island\nEast Sandrahaven, IA 22652',
#  '97653 Smith Fords\nLake Vanessa, MI 93813',
#  '946 Rebecca Glen\nLaurastad, MD 48491',
#  '1691 Morales Mews Apt. 581\nSouth Alan, WI 16809',
#  '0674 Shannon Hill Suite 455\nSimsshire, AL 51900',
#  '0426 Mendez Mills\nGonzalezfurt, UT 61201',
#  '72865 Carroll Road Apt. 082\nRickyburgh, LA 87935',
#  '0183 Lyons Unions Apt. 098\nKathryntown, RI 13704',
#  '1438 Anthony Knoll\nWilliammouth, NM 72613',
#  '5998 John Ford\nPort Wendy, IA 99380',
#  '51229 Goodwin Curve\nAshleyland, CT 68503',
#  '8090 Rios Cliffs\nRebeccafurt, WA 35338',
#  '763 Michael Wall Suite 996\nCatherinemouth, ME 46673',
#  '709 Melendez Way\nBellton, WV 74880',
#  '5562 Lewis Via Suite 707\nLewisport, UT 63759',
#  '4175 Robert Drive Apt. 355\nGonzalesview, ME 44493',
#  '8692 Barrett Inlet Apt. 849\nEvansberg, LA 98858',
#  '161 Cummings Valleys Apt. 406\nPort Austinport, AR 63728',
#  '33733 Mcknight Station Suite 524\nEast Katie, ND 56829',
#  '80045 Richard Hill Suite 774\nPort Paulfort, AL 83489',
#  '575 Lang Rue Suite 662\nPort Brandontown, MO 66813',
#  '6389 Jennifer Forest Apt. 920\nEast Ashley, HI 01387',
#  '79853 Laura Green\nBrandonfurt, WA 89156',
#  '755 Fields Station\nPort Cynthiaside, NE 47454',
#  'USS Wright\nFPO AE 26620',
#  '803 Hannah Mountains\nWest Ariel, LA 69951',
#  '6008 Antonio Cliff\nNorth Nathantown, VA 31779',
#  '845 Virginia Haven\nCarrburgh, MD 37908',
#  '983 Kimberly Points\nBanksview, OK 10949',
#  '281 Kelly Turnpike Apt. 286\nSouth Michelle, NH 67890',
#  '689 Allen Ranch\nNorth Saratown, SD 12542',
#  '964 John Rue\nEast Ashleyburgh, SC 91966',
#  '892 Hayes Tunnel Apt. 982\nJanetchester, NE 27832',
#  '5645 Jacqueline Pike Apt. 241\nRichardchester, VA 80868',
#  '14020 Jay Mountain\nAmandaside, SD 23702',
#  '4256 Emily Well\nJosephmouth, NE 15018',
#  '06659 Skinner Courts Suite 000\nLarryfort, AR 25879',
#  '25352 Keith Meadow Apt. 840\nOmarfurt, AK 86398',
#  '0618 Makayla Mount\nLake Craig, WV 31864',
#  '81939 Moore Estate Suite 600\nMartinborough, MA 57556',
#  '42551 Jeffery Parks Apt. 753\nJacksonmouth, NE 87551',
#  '276 Christine Mountains\nBrewerville, TX 83235',
#  '98671 Williams Harbors Suite 561\nNorth Brookemouth, KY 11292',
#  '645 James Ways Suite 077\nEast Kevinmouth, OH 30683',
#  '4146 Tina Rue\nBoothstad, PA 23363',
#  '52722 Ronald Points Apt. 744\nBarrettside, SD 79534',
#  '32857 Robert Groves Apt. 985\nLake Kenneth, TX 33455',
#  '19828 Rick Ville Apt. 931\nSouth Tiffany, CO 50300',
#  '700 Lynn Rapid Apt. 186\nSmithfurt, PA 46694',
#  '7063 Timothy Forest Suite 166\nNew Daniel, NE 84433',
#  '32931 Alvarez Pass\nEugenefort, MI 26424',
#  '650 Murphy Centers Apt. 112\nWest Christopherbury, DC 56752',
#  '4613 Hogan Expressway\nLake Hector, MS 81663',
#  '505 Phillips Manors Apt. 335\nEast Jessica, WY 82164',
#  '824 Wiley Mountains Apt. 042\nNorth Allison, WI 83211',
#  '7374 Sharon Mountains\nNew Georgebury, NY 41821',
#  '884 Kathryn Freeway\nMaddenland, PA 28521',
#  '8360 Charlene Turnpike\nBarrytown, RI 00957',
#  '60782 Nathaniel Knolls\nNew Robertshire, MO 80554',
#  '86539 Moore Ways Suite 966\nNew Laurashire, TN 18266',
#  '7552 Hayes Oval Apt. 242\nCastilloport, NC 87112',
#  '9261 Cook Estate Suite 874\nNew Alexisbury, WY 42022',
#  '0311 Laura Cliffs Suite 615\nWilliamsborough, NJ 04830',
#  '28445 Harris Avenue Apt. 020\nNorth Stacyshire, VA 77538',
#  '5915 Humphrey View Apt. 247\nPort Mary, MO 06637',
#  '3106 Davis Summit\nBrooksburgh, ND 25940',
#  '83454 Cheryl Springs Suite 193\nSouth Johnchester, HI 35059',
#  '37861 Aaron Haven Suite 190\nGarciashire, HI 25529',
#  '237 Martha Shoals\nEast Derrickstad, AZ 73677',
#  '88598 Cardenas Squares Apt. 647\nSouth Dalton, CT 49594',
#  '5267 Joyce Estate Apt. 714\nPort Sandra, DC 43615',
#  '1517 Teresa Loop Apt. 720\nPort Karlhaven, VA 62054',
#  '14145 Santos Vista\nPort Clinton, NM 90721',
#  '26843 Patrick Drives Suite 387\nTimothytown, ME 95000',
#  '453 Huerta Haven Suite 328\nChristopherburgh, NE 25349',
#  '730 Cochran Wall Suite 801\nYoungland, KS 48059',
#  '393 Kelly Harbor\nHillmouth, CT 29975',
#  '258 Emily Roads Suite 088\nLake Tiffanyburgh, NH 68613',
#  '43835 Young Villages Apt. 412\nRiveratown, IN 28333',
#  '91700 Miller Junctions Apt. 010\nRachelfurt, NC 75361',
#  '7106 Yvonne Wells\nBrookefurt, MI 18668',
#  '556 Julie Stream Apt. 601\nRichardberg, WY 33057',
#  '0548 Humphrey Vista\nHannahport, MS 34042',
#  '991 Kevin Villages Suite 278\nSouth Cameron, AZ 53028',
#  '722 Hicks Meadows\nLopezhaven, VT 98495',
#  '9564 Jeffery Estate\nWest Tylermouth, AZ 30171',
#  '1238 Kyle Knoll Suite 569\nPort Jasonville, CT 28458',
#  '73073 Williams Mills Suite 762\nWest Rebecca, RI 60858',
#  '72187 Mcgee Way\nTurnerhaven, AK 36794',
#  '7040 Sharon Lodge Apt. 377\nEast Brad, AK 75880',
#  'USS Maynard\nFPO AE 46069',
#  '2194 Cruz Brook\nHeatherport, NJ 21655',
#  '72927 Robinson Unions Apt. 618\nKyleborough, NC 90267',
#  '83771 Brooke Mountain Suite 706\nNorth Jacktown, OH 95736',
#  '62786 Maria Key\nLake Erikport, AL 55305',
#  '815 Deborah Extensions\nNorth Patricialand, PA 77684',
#  '3865 Gordon Greens Apt. 186\nJosephchester, NH 28659',
#  '40340 Eric Garden\nJosephfort, ID 22814',
#  '28539 Mcclure Trafficway Suite 755\nSouth Judy, ME 89788',
#  '46061 Barton Parkway Suite 057\nPort Petertown, CO 13164',
#  '1464 Chandler Ville\nWest Jeffreyburgh, HI 56593',
#  '885 Gloria Drive Apt. 390\nHayesstad, SC 38144',
#  '8031 Carrillo Mission Suite 786\nEast Williamberg, NV 81999',
#  '80176 John Points\nStevensport, NE 80405',
#  '920 Mcgee Gateway Suite 118\nPort Paula, SC 15985',
#  '4740 Michael Dale Suite 001\nReyeston, IN 73907',
#  '08291 Patricia Pass Suite 795\nNicoleview, NH 46259',
#  '626 Jackson Mews\nSanchezmouth, OK 04197',
#  '3021 Pineda Fort Apt. 892\nJasonburgh, NM 83207',
#  '21143 Lisa Mission Suite 809\nSamanthastad, CT 38781',
#  '72042 White Park\nKyleton, VA 92317',
#  '397 Owens Cliffs\nMichaeltown, CA 18123',
#  '76538 Meyer Square\nLake Claireport, MA 89479',
#  '34985 Lisa River Suite 995\nLake Kristentown, SC 49681',
#  '397 Wilson Ridges Suite 593\nZavalafort, CO 14218',
#  '4760 White Field\nHowardview, FL 61350',
#  '6639 Donald Shoals\nWest Tinatown, NE 36142',
#  '549 Francis Junctions Apt. 184\nBenjaminfurt, OK 38401',
#  '12640 Chase Stream Suite 521\nTiffanystad, TN 18040',
#  '8488 Natalie Points\nColleenport, VA 78615',
#  '08780 Kaitlyn Road\nSouth Cristina, MO 29821',
#  '744 Richard Cliff\nKarenbury, GA 44592',
#  '01828 Evans Mountain\nJenniferport, MN 45880',
#  '9373 Walker Village Suite 025\nSouth Janiceview, IN 50026',
#  '9506 Stewart Dale\nMaryshire, IA 28463',
#  '50342 Denise Radial\nSouth Melissa, CA 82927',
#  '582 Jonathan Divide Apt. 811\nAlexanderberg, IA 54531',
#  '925 Gray Brooks Suite 785\nDavidfort, MI 77373',
#  '564 Gallegos Ranch Suite 781\nJohnsonfort, WV 84038',
#  'USCGC Wells\nFPO AP 17268',
#  '182 John Rapids Suite 508\nCampbellborough, ID 45641',
#  'USCGC Vasquez\nFPO AE 08545',
#  '219 Harris Circles Apt. 764\nWest Ricardoport, OH 76299',
#  'USNS Yoder\nFPO AP 83316',
#  '08277 Lee Track Suite 304\nNorth Lisa, MS 33754',
#  '07241 Michael Hill\nEast Courtneyland, KS 11019']

# %% [markdown]
# # If the Beggining of Address is NOT a digit [0-9] sequence:
# + you have a military address, in this instance!
#
# Because, I already removed the PO BOX's

# %%
store_address=[]
military_addr=[]
match_word_pobox=re.compile(r'^[\d]{1,6}.+[\s\w.+].+')

for i in no_pobox: 
    if re.findall(match_word_pobox,i):
        store_address.extend(re.findall(match_word_pobox,i))
    else:
        military_addr.extend([i])

military_addr
store_address
# Out:
# ['74187 Laurie Parkways Apt. 344\nLake Maria, MN 77577',
#  '4035 Perez Pass Apt. 421\nCalderonton, KS 89435',
#  '0086 Cohen Trafficway\nNorth Joseph, WV 50669',
#  '4637 Mary Inlet Apt. 200\nNew Robert, ME 48035',
#  '36411 Schwartz Shoals Suite 648\nEast Denise, NV 66145',
#  '811 Johnson Garden Suite 506\nYolandafort, RI 63534',
#  '976 Amanda Common Suite 647\nChristianchester, VT 25717',
#  '0259 Douglas Gardens\nNew Aliciaberg, NM 73609',
#  '372 Wilson Common\nLake Latasha, MA 90202',
#  '667 Andrea Divide Suite 768\nRubenbury, RI 76156',
#  '81186 Frank Ports Suite 654\nDebrafort, NE 47710',
#  '6325 Morse Pine Apt. 801\nRobertoburgh, MN 50010',
#  '5266 Hart Burgs Suite 937\nMoorebury, MO 58963',
#  '804 Hester Station Suite 574\nEast John, OH 02675',
#  '227 Melissa Fields Suite 756\nDavidborough, OH 69897',
#  '906 Karen Loaf\nLake Jason, NY 87552',
#  '5517 Teresa Drive\nEast Mason, TN 57993',
#  '5702 Joshua Alley Suite 392\nBryanthaven, WY 33452',
#  '499 Michael Shores\nSouth Brenda, AR 44326',
#  '8309 Nichols Ford Apt. 391\nWilliambury, LA 67738',
#  '683 Nunez Parkway Suite 561\nOdonnellborough, NE 81031',
#  '8679 Young Stravenue Suite 338\nWestview, FL 29654',
#  '89049 Jessica Road\nWest Meagan, OH 88771',
#  '2694 Mcmillan Light Suite 626\nWangchester, CO 59661',
#  '63991 Lee Station\nClarencetown, DC 37301',
#  '0384 Carrie Mills\nChanburgh, MT 24541',
#  '239 Nichole Station\nEast Cameron, MS 80908',
#  '082 Hood Passage Suite 334\nDawnmouth, SD 10335',
#  '36121 Travis Forks Apt. 236\nNew Paigechester, OR 96454',
#  '927 Donald Turnpike\nLake Edwardmouth, CT 14757',
#  '982 Avery Track Suite 934\nOconnellside, LA 30835',
#  '1283 Jonathan Springs\nVictoriaport, WV 88955',
#  '007 Carla Parkway\nPorterbury, NJ 83519',
#  '2465 Gerald Mews\nPort Michael, NM 77520',
#  '067 Adam Ville Suite 997\nWest Derrickborough, MI 35864',
#  '93956 Steven View Apt. 748\nWest Andrea, MS 47690',
#  '6071 Zachary Mall\nNorth Grace, FL 15686',
#  '8106 Contreras Landing\nEast Stephanieshire, AK 90567',
#  '64316 Jennifer Fort Suite 264\nWest Nicolasfort, GA 97504',
#  '941 Jeremy Rest Apt. 486\nEast Allison, MD 48851',
#  '778 Steve Key\nLake Chad, KS 81740',
#  '0051 Smith Throughway Apt. 996\nPort Donna, OH 15666',
#  '9851 Anderson Mills Suite 176\nEast Luke, LA 85007',
#  '8010 Ramirez Club Apt. 824\nSouth Johnhaven, MA 37605',
#  '8487 Lawrence Unions Apt. 567\nKellyberg, DE 81275',
#  '41419 Aguilar Throughway\nEast Jeffreyborough, LA 42663',
#  '937 Amy Square Apt. 487\nCrystalshire, MS 78445',
#  '823 Hamilton Forges\nLake Dennis, NM 86895',
#  '6079 Mahoney Highway\nNew Gary, OK 84354',
#  '84788 Campos Pike\nFreemanstad, WV 61997',
#  '450 Brian Passage\nNorth Jamesville, SC 15291',
#  '92345 Terrence Green\nLake Cynthia, WI 72609',
#  '9526 Keith Mountains\nJulieborough, NE 74563',
#  '315 Brandon Harbors\nEast Benjaminland, MI 57476',
#  '3784 Chen Estate\nEast Carmen, HI 93102',
#  '255 Camacho Street Apt. 674\nJimmyport, AL 29627',
#  '2257 Samantha Track Suite 699\nNorth Laurie, TN 68112',
#  '48146 Martin Shore\nChristopherland, TX 75493',
#  '9301 Gregory Center\nHooperbury, MS 64382',
#  '7752 Garner Bypass\nLake Cristianview, VT 47099',
#  '775 Frank Gateway Suite 399\nTapiamouth, FL 87450',
#  '632 Macdonald Locks Apt. 126\nSouth Joseph, NE 60938',
#  '24765 Gregory Haven\nLeemouth, NJ 94248',
#  '80956 Julia Centers Apt. 765\nNew Lisa, TN 59234',
#  '78599 Scott Centers\nLake Maurice, MN 38430',
#  '886 Hall Streets\nEast Michael, MA 32110',
#  '7104 Jackson Throughway\nPort Miguelburgh, MO 58453',
#  '8223 Brian Summit\nWebbburgh, ME 43060',
#  '197 Rose Cape\nPort Meganhaven, DE 44288',
#  '4174 Corey Union Apt. 731\nBethanyview, AK 76453',
#  '23770 Murphy Ridges Suite 546\nEast Johnchester, UT 08945',
#  '501 Mitchell Flats Apt. 808\nKylebury, NM 77480',
#  '35345 Moore Plains Suite 101\nNew Lindaborough, ND 64886',
#  '8285 Vanessa Bypass Suite 779\nAnnetteberg, MI 73041',
#  '99739 Ashley Rue\nAlvaradochester, MD 59304',
#  '34554 Hoffman Street\nLisatown, AK 72249',
#  '958 Moody Mount Apt. 787\nCrystalhaven, SD 08559',
#  '84025 Steele Neck Suite 578\nNew Jacob, NE 96300',
#  '53853 Torres Ports\nNew Bethberg, RI 53889',
#  '741 Mario Extension Apt. 219\nJacksonborough, NV 46391',
#  '284 Meghan Way\nWagnerbury, CO 56330',
#  '18877 Perez Burg\nDiazberg, MN 37514',
#  '73318 Anderson Passage Apt. 976\nNew Ryan, VT 99408',
#  '353 Andrew Estates Apt. 598\nLewismouth, WY 37460',
#  '602 Scott Flats\nWest Brian, MS 19093',
#  '0260 Williams Glen Apt. 745\nEast Nicholas, CT 41968',
#  '02024 Elizabeth Fords Suite 697\nJohnstonchester, MD 69392',
#  '8901 Jennifer Fields\nJosephbury, SC 15238',
#  '3541 Vega Prairie Apt. 067\nPort Leahmouth, DC 52797',
#  '25873 Gomez Key Suite 172\nLake Shellyton, IN 06390',
#  '567 April Manor\nRiveraville, NE 51210',
#  '21794 Brandi Spur\nNorth Kristin, NY 07562',
#  '43833 Smith Pass\nNew Scott, CA 91552',
#  '42469 Lloyd Isle Suite 177\nNew Deborahfort, DE 26666',
#  '799 Pena Squares Suite 567\nEast Rodneyfort, CT 37704',
#  '303 Cindy Springs Suite 588\nFernandezland, WI 87118',
#  '477 Tammy Fall Suite 288\nNavarroton, VT 87014',
#  '305 Gray Inlet\nStephanieton, GA 64285',
#  '134 Wagner Street\nWilliamsbury, IA 75602',
#  '476 Potter Roads\nDeckerhaven, MD 92255',
#  '910 Green Run\nHollowaybury, RI 55379',
#  '7549 Salinas Meadow Apt. 147\nHortonstad, AL 30887',
#  '869 Patrick Lock\nStrongmouth, ID 67242',
#  '58902 Brenda Shoal Apt. 406\nLake Michael, AK 92604',
#  '1529 Moore Lock\nEast Jessicaborough, IL 29749',
#  '5671 Brent Lake\nJamesbury, DE 63032',
#  '15842 Kathy Island Suite 667\nGabriellaville, MD 55348',
#  '146 Baker Vista Suite 132\nLake Louisland, MO 98682',
#  '78159 Andrews Plaza\nCoxberg, TX 04469',
#  '3694 Marcus Crest Suite 900\nStuartborough, MA 62279',
#  '96479 Perez Ville Suite 873\nWalkerberg, CA 97733',
#  '643 Clarke Manors Apt. 056\nEast Michaelland, MO 39259',
#  '4923 Toni Lane\nKyleport, KS 09837',
#  '3408 Sarah Stravenue Suite 528\nLake Jonathanshire, WV 99177',
#  '486 Taylor Ways Apt. 443\nBurchborough, AZ 11143',
#  '39204 Spencer Coves Apt. 857\nEast Brandon, IN 69031',
#  '02806 Noah Mountains\nJasonburgh, MO 27388',
#  '62568 Rush Point\nNew Cameron, GA 20222',
#  '0619 Steven Crest\nVictorfort, WA 58860',
#  '710 Felicia Dam\nHartmanport, SD 37384',
#  '9717 Kelly Ports\nAlisonside, NH 95813',
#  '917 David Locks Suite 044\nLake Jamieport, NE 60827',
#  '658 Drake Street Apt. 900\nSouth Frankshire, MS 19961',
#  '6079 Travis Trace Apt. 000\nWest Joshuaville, NC 98345',
#  '07725 Melinda Squares Apt. 377\nEast Amyfurt, OK 69416',
#  '546 Sawyer Summit Apt. 600\nLopezville, RI 71955',
#  '52857 Lewis Extension\nKevinton, AR 34667',
#  '160 Brooke Wells Suite 758\nWilsonchester, ND 83410',
#  '57891 Foley Burgs\nNorth Ashley, AZ 63751',
#  '2898 Justin Mall\nPort Cherylhaven, TX 58787',
#  '8022 Bray Harbors\nHesterfurt, TN 30095',
#  '2236 Benjamin Tunnel Apt. 190\nNew Courtneybury, SD 87573',
#  '889 Michael Park\nNorrismouth, CT 64653',
#  '8099 Fuentes Oval\nGarciaborough, KY 50446',
#  '39403 Edwards Ways Apt. 567\nMelindaberg, MD 44325',
#  '133 Antonio Estates Apt. 367\nFoxshire, NC 86707',
#  '719 Sara Villages\nJustinmouth, NH 36813',
#  '9711 Timothy Neck Suite 727\nMadisonbury, OH 77458',
#  '995 Morgan Lodge\nAndersonview, GA 94018',
#  '95454 Kimberly Forest Apt. 522\nNguyenshire, MA 49938',
#  '192 Miller Harbors Apt. 666\nRickchester, OH 77901',
#  '3739 Jason Island Suite 484\nBrownshire, ME 32960',
#  '5185 John Forges Apt. 083\nHallton, UT 58189',
#  '887 Hayes Divide\nSouth Kellyport, KY 03217',
#  '9005 Michael Union\nRhondaton, CA 73750',
#  '2711 Jasmine Inlet\nPort Kayla, WI 17939',
#  '7517 Powell Points Suite 892\nBestfurt, ID 49545',
#  '82143 Pittman Lights\nWest Paul, CO 92690',
#  '606 Kathleen Square\nEast Shaneberg, MN 37391',
#  '0761 George Garden\nRojasstad, WA 62820',
#  '71018 Matthew Well Apt. 571\nMooreview, KS 38167',
#  '4093 Michael Plains\nWest Christine, WA 89000',
#  '3750 Sanders Garden\nEast Amanda, WY 62208',
#  '4056 Molly Falls\nWest Brianmouth, PA 46280',
#  '6378 Pearson Lakes\nRobertschester, OR 66112',
#  '31366 Lopez Circles\nChristopherview, NH 90065',
#  '95168 Katherine Gardens\nMooreland, NM 10210',
#  '588 Carter Mission Suite 606\nSouth Christopher, OH 75072',
#  '7293 Jennifer Drives\nJosephborough, AZ 53348',
#  '5026 Duran Motorway Suite 434\nAndreabury, AL 12926',
#  '934 Foster Creek\nNorth Roberttown, ME 62705',
#  '72952 Wheeler Forks\nTurnermouth, NM 17467',
#  '248 Sanders Fields Apt. 230\nMarytown, MA 26192',
#  '03317 Fuller Falls\nLake Christopher, MD 60015',
#  '4872 Guzman Prairie\nPort Joseph, DC 91142',
#  '456 Reyes Path\nSouth Crystaltown, NC 27087',
#  '47113 David Lake Suite 697\nDavidside, TN 84401',
#  '6779 Marie Vista Apt. 772\nBarnesstad, ID 47897',
#  '591 Paula Trace\nPort Mariahaven, NM 47716',
#  '8704 Williams Bridge\nSellersport, IL 14704',
#  '41700 Smith Port Apt. 857\nPort Shawnville, CT 32722',
#  '803 Kathleen Lodge Apt. 756\nNew Charles, NV 12104',
#  '916 Meadows Route Apt. 748\nCollinsberg, MT 58671',
#  '6242 Gabriel Flat Apt. 868\nDeleonland, NH 79429',
#  '62595 Tyler Extensions Apt. 327\nRyantown, ME 10934',
#  '69958 Bell Place\nNorth Robert, NJ 49636',
#  '098 Duran Light\nRileyshire, MS 20227',
#  '24213 Michael Neck\nSouth Peter, OK 77003',
#  '175 Mayo Rest Apt. 094\nJonesburgh, CA 03643',
#  '34716 Kristin Rapids Apt. 386\nSmithville, MN 85980',
#  '546 Jason Terrace\nJessicachester, MI 92559',
#  '2600 Melissa Plains\nRonaldburgh, FL 65979',
#  '72914 Campbell Avenue Suite 794\nPort Alex, OK 20389',
#  '058 Anthony Shore Suite 376\nCurtishaven, WI 32669',
#  '96376 Nathan Rue Apt. 728\nGriffithton, KY 61692',
#  '3531 Lisa Club\nNew Danielfort, CO 98212',
#  '0053 Rebecca Wells\nHuntermouth, AR 71885',
#  '98980 Lori Motorway Suite 656\nClarkland, VT 61706',
#  '89628 Tonya Light\nLoriburgh, HI 89949',
#  '837 Kelly Expressway Suite 778\nJacksonside, MT 98285',
#  '9811 Aguirre Key\nDorothyland, GA 72399',
#  '7936 Ann Pine Apt. 646\nColonstad, LA 70065',
#  '3370 Thomas Stream\nBakerland, RI 25912',
#  '08232 Marisa Port Apt. 080\nWest Gregory, MS 83637',
#  '688 Jason Hollow Suite 693\nJessicaborough, MA 05593',
#  '11650 Trevino Estates Suite 079\nAngelicamouth, KY 06685',
#  '48072 Rivera Bridge Suite 386\nNew Lisaland, NV 34121',
#  '4606 Toni Heights\nNew Mark, ME 10458',
#  '2612 Johnson Rue\nEast Timothyville, WY 74175',
#  '7567 Clayton Pine\nNorth Pamelabury, AL 01024',
#  '2741 Brittany Falls Apt. 193\nTerrencebury, KS 78234',
#  '055 Glover Mount Apt. 337\nDanielsborough, NV 42949',
#  '80462 Martin Ville Apt. 261\nLake Sydneymouth, NV 36477',
#  '890 Vicki Junction\nPatriciastad, CO 45847',
#  '901 Karen Heights\nRussellfort, AZ 78244',
#  '568 Matthew Turnpike Apt. 576\nMitchellborough, CA 86173',
#  '009 Brian Curve\nVillegashaven, VA 04688',
#  '00860 Lucas Island\nNorth Kyle, NM 07642',
#  '6010 Alvarado Corners\nAnneburgh, NM 49364',
#  '973 Bradley Burg Apt. 327\nHernandezshire, KS 16484',
#  '1531 Smith Meadow\nKrystalland, TX 81137',
#  '614 Jackson Court Apt. 205\nSouth Ashleyburgh, UT 55993',
#  '62535 Matthew Stream\nNorth Jonathon, RI 63820',
#  '0684 Jacob Summit Apt. 843\nJohnberg, ME 15133',
#  '73636 Leon Crescent\nEast Kevin, NC 80157',
#  '075 Todd Crossroad\nWest Jasonland, WY 55084',
#  '43125 Daniels Shores Apt. 765\nEast Charles, MA 72926',
#  '34799 Chavez Spurs\nNew Mariahland, ND 86671',
#  '848 Hickman Mills\nNicholasfurt, VT 87679',
#  '088 James Lakes\nSamanthaberg, AR 70563',
#  '875 Warren Land\nNorth Patrick, AK 87618',
#  '273 Tammy Drive Apt. 286\nLake Michelleport, UT 27222',
#  '00695 Lauren Crest\nNew Donaldfort, IA 15089',
#  '21552 Brandon Valley Apt. 711\nNorth Laurabury, MA 08841',
#  '6313 Hayes Plain Suite 544\nGriffinton, IN 84770',
#  '840 Moore Summit Apt. 279\nBradyton, UT 68575',
#  '338 Steven Mount\nMarksville, AK 44723',
#  '33675 Snyder Ranch Apt. 729\nNew Michaelville, HI 31740',
#  '5531 Pearson Meadow\nNorth Michael, VT 88571',
#  '183 Erik Corners\nMarytown, NV 21963',
#  '47020 Hayes Brook\nWest Patricia, UT 96457',
#  '311 James Station Apt. 850\nPort Lauren, WI 52255',
#  '796 Walker Mall\nHessburgh, HI 39524',
#  '277 Rivera Inlet Apt. 080\nEast Anthonyville, VA 46530',
#  '82979 Robinson Trail\nPort Kristen, TN 32152',
#  '7947 Jeremiah Lights Suite 199\nStewartside, AL 20213',
#  '72382 Archer Point Apt. 237\nLake Laurenmouth, RI 43879',
#  '72944 Ashley Tunnel Apt. 592\nNorth Russell, MD 46214',
#  '93907 Evelyn Drive Apt. 796\nChambersview, MO 72305',
#  '863 Jackson Haven Apt. 590\nJuliaton, NM 30139',
#  '17635 Jonathan Knolls\nNew Andre, MD 87663',
#  '2469 Jordan Springs\nPort Bradleystad, NJ 96230',
#  '33229 Graves Flats Apt. 099\nNew Christopherland, NH 24920',
#  '576 James Manor\nSouth Barbaraborough, FL 39289',
#  '8347 Daniel Tunnel\nBriggsstad, IL 28101',
#  '86929 Vasquez Lake Suite 029\nSouth Elizabeth, OK 05666',
#  '0808 Garcia Loop\nNew Kelly, ME 22074',
#  '9584 Katherine Streets Suite 329\nWest Anthonyport, IL 46715',
#  '2782 Jacob Viaduct Apt. 851\nSouth Tracy, ND 24794',
#  '850 Jeffrey Parkway\nPort Laura, NC 68131',
#  '3537 Lance Fall Apt. 073\nNorth Michael, ND 00592',
#  '134 Turner Ville\nSmithborough, DE 92785',
#  '993 Smith Pine\nWest Catherinestad, WV 23443',
#  '604 Lisa Heights\nEast Jay, HI 82489',
#  '402 Thompson Center\nMichaeltown, NY 40664',
#  '53987 Wilson Street Suite 048\nWest Jadehaven, FL 82932',
#  '2883 Montgomery Tunnel\nNorth Kerri, DC 96960',
#  '4297 Brooks Causeway\nPort Annaton, DC 74227',
#  '22712 Lee Plain Suite 715\nCostaland, AR 04978',
#  '185 Jennifer Dam Apt. 277\nPort Rebekahchester, HI 05884',
#  '5423 Martin Inlet Suite 748\nHoganfurt, MT 83974',
#  '463 Cassidy Villages\nJohnfort, IN 75271',
#  '95913 York Drive\nBrownview, RI 13623',
#  '28086 Williams Cape\nWilliamstown, NE 66657',
#  '93312 Michael Port\nSouth Timothyville, CO 82892',
#  '7145 Rivera Islands Suite 470\nCopelandside, AK 94558',
#  '98407 Heidi Views\nNorth Luisberg, DC 84066',
#  '7302 Vicki Cliff Apt. 573\nKimberlyport, NE 84818',
#  '27753 Norris Burg\nPort Tommouth, OK 17173',
#  '1524 Underwood Neck\nNorth Juanton, IN 71759',
#  '1694 Lee Streets\nEast Kimberlyberg, SD 90567',
#  '0377 Reed Neck Suite 752\nRonaldbury, KS 80752',
#  '9102 Baker Mountain\nHornebury, OK 59407',
#  '9861 Hill Junctions\nWest Angelashire, WA 68720',
#  '1779 Allen Court Apt. 232\nWest Paulside, KS 24032',
#  '221 Matthew Mountain\nPhilipmouth, NE 21109',
#  '336 Robert Expressway Suite 049\nAndreafort, NH 63451',
#  '6699 Adam Extension\nRussellborough, VA 84984',
#  '41736 Nixon Station\nEast Paulaland, NJ 96656',
#  '2970 Turner Port\nAngelastad, WV 10037',
#  '55620 Adam Harbor Suite 261\nJohnsonland, KS 81445',
#  '9179 Mary Forks\nSouth Caseybury, AZ 93863',
#  '103 Bradley Fort\nRichardsonshire, FL 12523',
#  '868 Macias Islands\nLindaland, IA 55733',
#  '2495 Scott Keys Apt. 344\nEast Krystalburgh, SD 98772',
#  '5811 Santana Lodge\nDanielbury, TX 05072',
#  '0908 Justin Mountains Suite 469\nWest Anthony, CA 10238',
#  '691 Michael Lodge Apt. 455\nLake Markton, TN 58270',
#  '03528 Maria Road Suite 204\nChristybury, HI 31385',
#  '8107 Swanson Crossroad Apt. 601\nLake Nancyberg, IA 82877',
#  '19898 Daniel Freeway Apt. 286\nSheilaton, KS 29285',
#  '317 Silva Inlet Suite 027\nCastrofurt, ND 88450',
#  '223 Kathleen Vista\nWest Robertmouth, AL 07394',
#  '8725 Hurst Wall Suite 529\nWest Susan, IL 87362',
#  '429 Lauren Freeway\nAndersonview, KS 04491',
#  '6110 Stone Union Apt. 550\nLake Samuel, CT 49223',
#  '21354 Jason Crossing\nLake Annette, WA 69860',
#  '84682 Shaun Loaf\nLake Laurieville, OR 05972',
#  '7600 Matthew Stravenue Apt. 192\nJohnchester, IN 51531',
#  '8905 Janice Pine\nPort David, MD 53966',
#  '690 Flynn Brook\nGordonbury, HI 54285',
#  '73104 Smith Expressway Apt. 288\nEast Lisafort, IA 38293',
#  '48998 Zachary Crossing\nPort Joseph, UT 13653',
#  '985 Bolton Plaza Suite 079\nHughesfurt, DC 72683',
#  '19014 Jerry Forks Apt. 155\nHallchester, AK 29974',
#  '270 Angela Mountains\nJoshuachester, GA 76052',
#  '49791 Michael Port\nNorth Derrick, WV 09134',
#  '51091 Martin Cape Suite 471\nCummingsland, CA 28971',
#  '8720 Sosa Gardens\nEast Kathryntown, IA 31777',
#  '594 Edward Route Suite 041\nJeffreymouth, AZ 86613',
#  '79363 Ball Crossroad\nEast Jamesburgh, WI 59977',
#  '284 Brian Walks Suite 699\nSharonborough, AK 93518',
#  '2545 Clark Streets\nWest Ryanshire, GA 17748',
#  '11905 Brown Point\nLake Samantha, ND 43735',
#  '63305 Daniel Islands\nEast Ralphchester, KY 94427',
#  '7380 Hart Plains Apt. 774\nLake Katherineport, UT 88781',
#  '0271 Ricky Throughway\nWest Garyfort, NV 37079',
#  '035 Jenkins Island\nSouth Michaelland, RI 41838',
#  '639 Young Mews\nNew Chrismouth, NY 85067',
#  '323 Juarez Island\nAnthonymouth, UT 81458',
#  '3792 Mitchell Passage\nWagnerside, AK 48212',
#  '74325 Blankenship Island\nEast Sandrahaven, IA 22652',
#  '97653 Smith Fords\nLake Vanessa, MI 93813',
#  '946 Rebecca Glen\nLaurastad, MD 48491',
#  '1691 Morales Mews Apt. 581\nSouth Alan, WI 16809',
#  '0674 Shannon Hill Suite 455\nSimsshire, AL 51900',
#  '0426 Mendez Mills\nGonzalezfurt, UT 61201',
#  '72865 Carroll Road Apt. 082\nRickyburgh, LA 87935',
#  '0183 Lyons Unions Apt. 098\nKathryntown, RI 13704',
#  '1438 Anthony Knoll\nWilliammouth, NM 72613',
#  '5998 John Ford\nPort Wendy, IA 99380',
#  '51229 Goodwin Curve\nAshleyland, CT 68503',
#  '8090 Rios Cliffs\nRebeccafurt, WA 35338',
#  '763 Michael Wall Suite 996\nCatherinemouth, ME 46673',
#  '709 Melendez Way\nBellton, WV 74880',
#  '5562 Lewis Via Suite 707\nLewisport, UT 63759',
#  '4175 Robert Drive Apt. 355\nGonzalesview, ME 44493',
#  '8692 Barrett Inlet Apt. 849\nEvansberg, LA 98858',
#  '161 Cummings Valleys Apt. 406\nPort Austinport, AR 63728',
#  '33733 Mcknight Station Suite 524\nEast Katie, ND 56829',
#  '80045 Richard Hill Suite 774\nPort Paulfort, AL 83489',
#  '575 Lang Rue Suite 662\nPort Brandontown, MO 66813',
#  '6389 Jennifer Forest Apt. 920\nEast Ashley, HI 01387',
#  '79853 Laura Green\nBrandonfurt, WA 89156',
#  '755 Fields Station\nPort Cynthiaside, NE 47454',
#  '803 Hannah Mountains\nWest Ariel, LA 69951',
#  '6008 Antonio Cliff\nNorth Nathantown, VA 31779',
#  '845 Virginia Haven\nCarrburgh, MD 37908',
#  '983 Kimberly Points\nBanksview, OK 10949',
#  '281 Kelly Turnpike Apt. 286\nSouth Michelle, NH 67890',
#  '689 Allen Ranch\nNorth Saratown, SD 12542',
#  '964 John Rue\nEast Ashleyburgh, SC 91966',
#  '892 Hayes Tunnel Apt. 982\nJanetchester, NE 27832',
#  '5645 Jacqueline Pike Apt. 241\nRichardchester, VA 80868',
#  '14020 Jay Mountain\nAmandaside, SD 23702',
#  '4256 Emily Well\nJosephmouth, NE 15018',
#  '06659 Skinner Courts Suite 000\nLarryfort, AR 25879',
#  '25352 Keith Meadow Apt. 840\nOmarfurt, AK 86398',
#  '0618 Makayla Mount\nLake Craig, WV 31864',
#  '81939 Moore Estate Suite 600\nMartinborough, MA 57556',
#  '42551 Jeffery Parks Apt. 753\nJacksonmouth, NE 87551',
#  '276 Christine Mountains\nBrewerville, TX 83235',
#  '98671 Williams Harbors Suite 561\nNorth Brookemouth, KY 11292',
#  '645 James Ways Suite 077\nEast Kevinmouth, OH 30683',
#  '4146 Tina Rue\nBoothstad, PA 23363',
#  '52722 Ronald Points Apt. 744\nBarrettside, SD 79534',
#  '32857 Robert Groves Apt. 985\nLake Kenneth, TX 33455',
#  '19828 Rick Ville Apt. 931\nSouth Tiffany, CO 50300',
#  '700 Lynn Rapid Apt. 186\nSmithfurt, PA 46694',
#  '7063 Timothy Forest Suite 166\nNew Daniel, NE 84433',
#  '32931 Alvarez Pass\nEugenefort, MI 26424',
#  '650 Murphy Centers Apt. 112\nWest Christopherbury, DC 56752',
#  '4613 Hogan Expressway\nLake Hector, MS 81663',
#  '505 Phillips Manors Apt. 335\nEast Jessica, WY 82164',
#  '824 Wiley Mountains Apt. 042\nNorth Allison, WI 83211',
#  '7374 Sharon Mountains\nNew Georgebury, NY 41821',
#  '884 Kathryn Freeway\nMaddenland, PA 28521',
#  '8360 Charlene Turnpike\nBarrytown, RI 00957',
#  '60782 Nathaniel Knolls\nNew Robertshire, MO 80554',
#  '86539 Moore Ways Suite 966\nNew Laurashire, TN 18266',
#  '7552 Hayes Oval Apt. 242\nCastilloport, NC 87112',
#  '9261 Cook Estate Suite 874\nNew Alexisbury, WY 42022',
#  '0311 Laura Cliffs Suite 615\nWilliamsborough, NJ 04830',
#  '28445 Harris Avenue Apt. 020\nNorth Stacyshire, VA 77538',
#  '5915 Humphrey View Apt. 247\nPort Mary, MO 06637',
#  '3106 Davis Summit\nBrooksburgh, ND 25940',
#  '83454 Cheryl Springs Suite 193\nSouth Johnchester, HI 35059',
#  '37861 Aaron Haven Suite 190\nGarciashire, HI 25529',
#  '237 Martha Shoals\nEast Derrickstad, AZ 73677',
#  '88598 Cardenas Squares Apt. 647\nSouth Dalton, CT 49594',
#  '5267 Joyce Estate Apt. 714\nPort Sandra, DC 43615',
#  '1517 Teresa Loop Apt. 720\nPort Karlhaven, VA 62054',
#  '14145 Santos Vista\nPort Clinton, NM 90721',
#  '26843 Patrick Drives Suite 387\nTimothytown, ME 95000',
#  '453 Huerta Haven Suite 328\nChristopherburgh, NE 25349',
#  '730 Cochran Wall Suite 801\nYoungland, KS 48059',
#  '393 Kelly Harbor\nHillmouth, CT 29975',
#  '258 Emily Roads Suite 088\nLake Tiffanyburgh, NH 68613',
#  '43835 Young Villages Apt. 412\nRiveratown, IN 28333',
#  '91700 Miller Junctions Apt. 010\nRachelfurt, NC 75361',
#  '7106 Yvonne Wells\nBrookefurt, MI 18668',
#  '556 Julie Stream Apt. 601\nRichardberg, WY 33057',
#  '0548 Humphrey Vista\nHannahport, MS 34042',
#  '991 Kevin Villages Suite 278\nSouth Cameron, AZ 53028',
#  '722 Hicks Meadows\nLopezhaven, VT 98495',
#  '9564 Jeffery Estate\nWest Tylermouth, AZ 30171',
#  '1238 Kyle Knoll Suite 569\nPort Jasonville, CT 28458',
#  '73073 Williams Mills Suite 762\nWest Rebecca, RI 60858',
#  '72187 Mcgee Way\nTurnerhaven, AK 36794',
#  '7040 Sharon Lodge Apt. 377\nEast Brad, AK 75880',
#  '2194 Cruz Brook\nHeatherport, NJ 21655',
#  '72927 Robinson Unions Apt. 618\nKyleborough, NC 90267',
#  '83771 Brooke Mountain Suite 706\nNorth Jacktown, OH 95736',
#  '62786 Maria Key\nLake Erikport, AL 55305',
#  '815 Deborah Extensions\nNorth Patricialand, PA 77684',
#  '3865 Gordon Greens Apt. 186\nJosephchester, NH 28659',
#  '40340 Eric Garden\nJosephfort, ID 22814',
#  '28539 Mcclure Trafficway Suite 755\nSouth Judy, ME 89788',
#  '46061 Barton Parkway Suite 057\nPort Petertown, CO 13164',
#  '1464 Chandler Ville\nWest Jeffreyburgh, HI 56593',
#  '885 Gloria Drive Apt. 390\nHayesstad, SC 38144',
#  '8031 Carrillo Mission Suite 786\nEast Williamberg, NV 81999',
#  '80176 John Points\nStevensport, NE 80405',
#  '920 Mcgee Gateway Suite 118\nPort Paula, SC 15985',
#  '4740 Michael Dale Suite 001\nReyeston, IN 73907',
#  '08291 Patricia Pass Suite 795\nNicoleview, NH 46259',
#  '626 Jackson Mews\nSanchezmouth, OK 04197',
#  '3021 Pineda Fort Apt. 892\nJasonburgh, NM 83207',
#  '21143 Lisa Mission Suite 809\nSamanthastad, CT 38781',
#  '72042 White Park\nKyleton, VA 92317',
#  '397 Owens Cliffs\nMichaeltown, CA 18123',
#  '76538 Meyer Square\nLake Claireport, MA 89479',
#  '34985 Lisa River Suite 995\nLake Kristentown, SC 49681',
#  '397 Wilson Ridges Suite 593\nZavalafort, CO 14218',
#  '4760 White Field\nHowardview, FL 61350',
#  '6639 Donald Shoals\nWest Tinatown, NE 36142',
#  '549 Francis Junctions Apt. 184\nBenjaminfurt, OK 38401',
#  '12640 Chase Stream Suite 521\nTiffanystad, TN 18040',
#  '8488 Natalie Points\nColleenport, VA 78615',
#  '08780 Kaitlyn Road\nSouth Cristina, MO 29821',
#  '744 Richard Cliff\nKarenbury, GA 44592',
#  '01828 Evans Mountain\nJenniferport, MN 45880',
#  '9373 Walker Village Suite 025\nSouth Janiceview, IN 50026',
#  '9506 Stewart Dale\nMaryshire, IA 28463',
#  '50342 Denise Radial\nSouth Melissa, CA 82927',
#  '582 Jonathan Divide Apt. 811\nAlexanderberg, IA 54531',
#  '925 Gray Brooks Suite 785\nDavidfort, MI 77373',
#  '564 Gallegos Ranch Suite 781\nJohnsonfort, WV 84038',
#  '182 John Rapids Suite 508\nCampbellborough, ID 45641',
#  '219 Harris Circles Apt. 764\nWest Ricardoport, OH 76299',
#  '08277 Lee Track Suite 304\nNorth Lisa, MS 33754',
#  '07241 Michael Hill\nEast Courtneyland, KS 11019']

# %% [markdown]
# # Parse Addresses:

# %%
y=[]
for i in store_address:
    y.append(re.split(r'\n',i))
#     print(i)
y

# Digit address
primary_addr_num=re.compile(r'^[\d]+')

# Cardinal Direction: "Predirectional"
post_directional=re.compile(r'[^\d]+\w')

# Street Name
# street_name=

# Postdirection:
# post_dir =

# apt,ste,suite
secondary_adrr= re.compile(r'\b(?=((Apt|Suite|#)\S\s\w+))')

# City:

# State:

# Zipcode:

q='74187 Laurie Parkways Apt. 344 Lake Maria, MN 77577'
# re.findall(r'^[\d]+',q)

# %%
# Find Digit for Street Address:

q='74187 Laurie Parkways Apt. 344 Lake Maria, MN 77577'
re.findall(r'^[\d]+',q)
# Out:
# ['74187']

# %%
# Pre-Directional for Address:

q='74187 S.W. Laurie Parkways Apt. 344\nLake Maria, MN 77577'
predir_=re.findall(r'^[\d+]+\s(S(\s|\.|o|outh|[ewn]\s|e.|w.|n.)+|w(est|\.|\s)+|e(\.|ast)+)',
           q,flags=re.IGNORECASE)

predir_[0][0]
# re.findall(r'^[\d+].*\s[\w]\s',q)
# Out:
# 'S.W. '

# %%
# Find Apartment:


# re.findall(r'^[\d+].*\s[\w]\s',q)


io=re.findall(r'^[\d+]+\s\w\S\s\w+',q)

for i in io:
    print(re.findall(r'[^\d]+\w',i))

# %%
re.findall(re.compile(r'(?=Apt|Suite)\w\S+'),q)
# Out:
# ['Apt.']

# %%
# Apartment or Suite with number:

ui=re.findall(re.compile(r'\b(?=((Apt|Suite)\S\s\w+))'),q)
ui[0][0]
# ui
# Out:
# 'Apt. 344'

# %%
# Look Look Behind (POS): State and Zipcode

re.split('\n',q)

re.findall(r'(?<=\,).+',q)
# q
# Out:
# [' MN 77577']

# %%
re.findall(r'(?=\,).+',q)
# Out:
# [', MN 77577']

# %%
# LookForward: But, there is a hidden issue to discuss on line below!

re.findall(re.compile(r'.+?(?=\,)'),q)
# q
# Out:
# ['Lake Maria']

# %%
# City Addresses: first step

o=[]
for i in store_address:
    p=re.findall(re.compile(r'.+?(?=,)'),i)
    o.extend(p)
o
# Out:
# ['Lake Maria',
#  'Calderonton',
#  'North Joseph',
#  'New Robert',
#  'East Denise',
#  'Yolandafort',
#  'Christianchester',
#  'New Aliciaberg',
#  'Lake Latasha',
#  'Rubenbury',
#  'Debrafort',
#  'Robertoburgh',
#  'Moorebury',
#  'East John',
#  'Davidborough',
#  'Lake Jason',
#  'East Mason',
#  'Bryanthaven',
#  'South Brenda',
#  'Williambury',
#  'Odonnellborough',
#  'Westview',
#  'West Meagan',
#  'Wangchester',
#  'Clarencetown',
#  'Chanburgh',
#  'East Cameron',
#  'Dawnmouth',
#  'New Paigechester',
#  'Lake Edwardmouth',
#  'Oconnellside',
#  'Victoriaport',
#  'Porterbury',
#  'Port Michael',
#  'West Derrickborough',
#  'West Andrea',
#  'North Grace',
#  'East Stephanieshire',
#  'West Nicolasfort',
#  'East Allison',
#  'Lake Chad',
#  'Port Donna',
#  'East Luke',
#  'South Johnhaven',
#  'Kellyberg',
#  'East Jeffreyborough',
#  'Crystalshire',
#  'Lake Dennis',
#  'New Gary',
#  'Freemanstad',
#  'North Jamesville',
#  'Lake Cynthia',
#  'Julieborough',
#  'East Benjaminland',
#  'East Carmen',
#  'Jimmyport',
#  'North Laurie',
#  'Christopherland',
#  'Hooperbury',
#  'Lake Cristianview',
#  'Tapiamouth',
#  'South Joseph',
#  'Leemouth',
#  'New Lisa',
#  'Lake Maurice',
#  'East Michael',
#  'Port Miguelburgh',
#  'Webbburgh',
#  'Port Meganhaven',
#  'Bethanyview',
#  'East Johnchester',
#  'Kylebury',
#  'New Lindaborough',
#  'Annetteberg',
#  'Alvaradochester',
#  'Lisatown',
#  'Crystalhaven',
#  'New Jacob',
#  'New Bethberg',
#  'Jacksonborough',
#  'Wagnerbury',
#  'Diazberg',
#  'New Ryan',
#  'Lewismouth',
#  'West Brian',
#  'East Nicholas',
#  'Johnstonchester',
#  'Josephbury',
#  'Port Leahmouth',
#  'Lake Shellyton',
#  'Riveraville',
#  'North Kristin',
#  'New Scott',
#  'New Deborahfort',
#  'East Rodneyfort',
#  'Fernandezland',
#  'Navarroton',
#  'Stephanieton',
#  'Williamsbury',
#  'Deckerhaven',
#  'Hollowaybury',
#  'Hortonstad',
#  'Strongmouth',
#  'Lake Michael',
#  'East Jessicaborough',
#  'Jamesbury',
#  'Gabriellaville',
#  'Lake Louisland',
#  'Coxberg',
#  'Stuartborough',
#  'Walkerberg',
#  'East Michaelland',
#  'Kyleport',
#  'Lake Jonathanshire',
#  'Burchborough',
#  'East Brandon',
#  'Jasonburgh',
#  'New Cameron',
#  'Victorfort',
#  'Hartmanport',
#  'Alisonside',
#  'Lake Jamieport',
#  'South Frankshire',
#  'West Joshuaville',
#  'East Amyfurt',
#  'Lopezville',
#  'Kevinton',
#  'Wilsonchester',
#  'North Ashley',
#  'Port Cherylhaven',
#  'Hesterfurt',
#  'New Courtneybury',
#  'Norrismouth',
#  'Garciaborough',
#  'Melindaberg',
#  'Foxshire',
#  'Justinmouth',
#  'Madisonbury',
#  'Andersonview',
#  'Nguyenshire',
#  'Rickchester',
#  'Brownshire',
#  'Hallton',
#  'South Kellyport',
#  'Rhondaton',
#  'Port Kayla',
#  'Bestfurt',
#  'West Paul',
#  'East Shaneberg',
#  'Rojasstad',
#  'Mooreview',
#  'West Christine',
#  'East Amanda',
#  'West Brianmouth',
#  'Robertschester',
#  'Christopherview',
#  'Mooreland',
#  'South Christopher',
#  'Josephborough',
#  'Andreabury',
#  'North Roberttown',
#  'Turnermouth',
#  'Marytown',
#  'Lake Christopher',
#  'Port Joseph',
#  'South Crystaltown',
#  'Davidside',
#  'Barnesstad',
#  'Port Mariahaven',
#  'Sellersport',
#  'Port Shawnville',
#  'New Charles',
#  'Collinsberg',
#  'Deleonland',
#  'Ryantown',
#  'North Robert',
#  'Rileyshire',
#  'South Peter',
#  'Jonesburgh',
#  'Smithville',
#  'Jessicachester',
#  'Ronaldburgh',
#  'Port Alex',
#  'Curtishaven',
#  'Griffithton',
#  'New Danielfort',
#  'Huntermouth',
#  'Clarkland',
#  'Loriburgh',
#  'Jacksonside',
#  'Dorothyland',
#  'Colonstad',
#  'Bakerland',
#  'West Gregory',
#  'Jessicaborough',
#  'Angelicamouth',
#  'New Lisaland',
#  'New Mark',
#  'East Timothyville',
#  'North Pamelabury',
#  'Terrencebury',
#  'Danielsborough',
#  'Lake Sydneymouth',
#  'Patriciastad',
#  'Russellfort',
#  'Mitchellborough',
#  'Villegashaven',
#  'North Kyle',
#  'Anneburgh',
#  'Hernandezshire',
#  'Krystalland',
#  'South Ashleyburgh',
#  'North Jonathon',
#  'Johnberg',
#  'East Kevin',
#  'West Jasonland',
#  'East Charles',
#  'New Mariahland',
#  'Nicholasfurt',
#  'Samanthaberg',
#  'North Patrick',
#  'Lake Michelleport',
#  'New Donaldfort',
#  'North Laurabury',
#  'Griffinton',
#  'Bradyton',
#  'Marksville',
#  'New Michaelville',
#  'North Michael',
#  'Marytown',
#  'West Patricia',
#  'Port Lauren',
#  'Hessburgh',
#  'East Anthonyville',
#  'Port Kristen',
#  'Stewartside',
#  'Lake Laurenmouth',
#  'North Russell',
#  'Chambersview',
#  'Juliaton',
#  'New Andre',
#  'Port Bradleystad',
#  'New Christopherland',
#  'South Barbaraborough',
#  'Briggsstad',
#  'South Elizabeth',
#  'New Kelly',
#  'West Anthonyport',
#  'South Tracy',
#  'Port Laura',
#  'North Michael',
#  'Smithborough',
#  'West Catherinestad',
#  'East Jay',
#  'Michaeltown',
#  'West Jadehaven',
#  'North Kerri',
#  'Port Annaton',
#  'Costaland',
#  'Port Rebekahchester',
#  'Hoganfurt',
#  'Johnfort',
#  'Brownview',
#  'Williamstown',
#  'South Timothyville',
#  'Copelandside',
#  'North Luisberg',
#  'Kimberlyport',
#  'Port Tommouth',
#  'North Juanton',
#  'East Kimberlyberg',
#  'Ronaldbury',
#  'Hornebury',
#  'West Angelashire',
#  'West Paulside',
#  'Philipmouth',
#  'Andreafort',
#  'Russellborough',
#  'East Paulaland',
#  'Angelastad',
#  'Johnsonland',
#  'South Caseybury',
#  'Richardsonshire',
#  'Lindaland',
#  'East Krystalburgh',
#  'Danielbury',
#  'West Anthony',
#  'Lake Markton',
#  'Christybury',
#  'Lake Nancyberg',
#  'Sheilaton',
#  'Castrofurt',
#  'West Robertmouth',
#  'West Susan',
#  'Andersonview',
#  'Lake Samuel',
#  'Lake Annette',
#  'Lake Laurieville',
#  'Johnchester',
#  'Port David',
#  'Gordonbury',
#  'East Lisafort',
#  'Port Joseph',
#  'Hughesfurt',
#  'Hallchester',
#  'Joshuachester',
#  'North Derrick',
#  'Cummingsland',
#  'East Kathryntown',
#  'Jeffreymouth',
#  'East Jamesburgh',
#  'Sharonborough',
#  'West Ryanshire',
#  'Lake Samantha',
#  'East Ralphchester',
#  'Lake Katherineport',
#  'West Garyfort',
#  'South Michaelland',
#  'New Chrismouth',
#  'Anthonymouth',
#  'Wagnerside',
#  'East Sandrahaven',
#  'Lake Vanessa',
#  'Laurastad',
#  'South Alan',
#  'Simsshire',
#  'Gonzalezfurt',
#  'Rickyburgh',
#  'Kathryntown',
#  'Williammouth',
#  'Port Wendy',
#  'Ashleyland',
#  'Rebeccafurt',
#  'Catherinemouth',
#  'Bellton',
#  'Lewisport',
#  'Gonzalesview',
#  'Evansberg',
#  'Port Austinport',
#  'East Katie',
#  'Port Paulfort',
#  'Port Brandontown',
#  'East Ashley',
#  'Brandonfurt',
#  'Port Cynthiaside',
#  'West Ariel',
#  'North Nathantown',
#  'Carrburgh',
#  'Banksview',
#  'South Michelle',
#  'North Saratown',
#  'East Ashleyburgh',
#  'Janetchester',
#  'Richardchester',
#  'Amandaside',
#  'Josephmouth',
#  'Larryfort',
#  'Omarfurt',
#  'Lake Craig',
#  'Martinborough',
#  'Jacksonmouth',
#  'Brewerville',
#  'North Brookemouth',
#  'East Kevinmouth',
#  'Boothstad',
#  'Barrettside',
#  'Lake Kenneth',
#  'South Tiffany',
#  'Smithfurt',
#  'New Daniel',
#  'Eugenefort',
#  'West Christopherbury',
#  'Lake Hector',
#  'East Jessica',
#  'North Allison',
#  'New Georgebury',
#  'Maddenland',
#  'Barrytown',
#  'New Robertshire',
#  'New Laurashire',
#  'Castilloport',
#  'New Alexisbury',
#  'Williamsborough',
#  'North Stacyshire',
#  'Port Mary',
#  'Brooksburgh',
#  'South Johnchester',
#  'Garciashire',
#  'East Derrickstad',
#  'South Dalton',
#  'Port Sandra',
#  'Port Karlhaven',
#  'Port Clinton',
#  'Timothytown',
#  'Christopherburgh',
#  'Youngland',
#  'Hillmouth',
#  'Lake Tiffanyburgh',
#  'Riveratown',
#  'Rachelfurt',
#  'Brookefurt',
#  'Richardberg',
#  'Hannahport',
#  'South Cameron',
#  'Lopezhaven',
#  'West Tylermouth',
#  'Port Jasonville',
#  'West Rebecca',
#  'Turnerhaven',
#  'East Brad',
#  'Heatherport',
#  'Kyleborough',
#  'North Jacktown',
#  'Lake Erikport',
#  'North Patricialand',
#  'Josephchester',
#  'Josephfort',
#  'South Judy',
#  'Port Petertown',
#  'West Jeffreyburgh',
#  'Hayesstad',
#  'East Williamberg',
#  'Stevensport',
#  'Port Paula',
#  'Reyeston',
#  'Nicoleview',
#  'Sanchezmouth',
#  'Jasonburgh',
#  'Samanthastad',
#  'Kyleton',
#  'Michaeltown',
#  'Lake Claireport',
#  'Lake Kristentown',
#  'Zavalafort',
#  'Howardview',
#  'West Tinatown',
#  'Benjaminfurt',
#  'Tiffanystad',
#  'Colleenport',
#  'South Cristina',
#  'Karenbury',
#  'Jenniferport',
#  'South Janiceview',
#  'Maryshire',
#  'South Melissa',
#  'Alexanderberg',
#  'Davidfort',
#  'Johnsonfort',
#  'Campbellborough',
#  'West Ricardoport',
#  'North Lisa',
#  'East Courtneyland']

# %%
# City: Second Step

streets=[]
for j in o:
    pp=re.sub('North|South|West|East','',j)
    streets.append(pp.lstrip())
#     print(j)
streets[:4]
# streets
# Out:
# ['Lake Maria', 'Calderonton', 'Joseph', 'New Robert']

# %%
# Divided State & Zipcode:

state_zip=[]
for i in store_address:
    state_zip.extend(re.findall(r'(?<=\,).+',i))
state_zip_=[]    
for j in state_zip:
    state_zip_.extend([j.lstrip().replace(' ',',').split(',')])
state_zip_
# state_zip
# Out:
# [['MN', '77577'],
#  ['KS', '89435'],
#  ['WV', '50669'],
#  ['ME', '48035'],
#  ['NV', '66145'],
#  ['RI', '63534'],
#  ['VT', '25717'],
#  ['NM', '73609'],
#  ['MA', '90202'],
#  ['RI', '76156'],
#  ['NE', '47710'],
#  ['MN', '50010'],
#  ['MO', '58963'],
#  ['OH', '02675'],
#  ['OH', '69897'],
#  ['NY', '87552'],
#  ['TN', '57993'],
#  ['WY', '33452'],
#  ['AR', '44326'],
#  ['LA', '67738'],
#  ['NE', '81031'],
#  ['FL', '29654'],
#  ['OH', '88771'],
#  ['CO', '59661'],
#  ['DC', '37301'],
#  ['MT', '24541'],
#  ['MS', '80908'],
#  ['SD', '10335'],
#  ['OR', '96454'],
#  ['CT', '14757'],
#  ['LA', '30835'],
#  ['WV', '88955'],
#  ['NJ', '83519'],
#  ['NM', '77520'],
#  ['MI', '35864'],
#  ['MS', '47690'],
#  ['FL', '15686'],
#  ['AK', '90567'],
#  ['GA', '97504'],
#  ['MD', '48851'],
#  ['KS', '81740'],
#  ['OH', '15666'],
#  ['LA', '85007'],
#  ['MA', '37605'],
#  ['DE', '81275'],
#  ['LA', '42663'],
#  ['MS', '78445'],
#  ['NM', '86895'],
#  ['OK', '84354'],
#  ['WV', '61997'],
#  ['SC', '15291'],
#  ['WI', '72609'],
#  ['NE', '74563'],
#  ['MI', '57476'],
#  ['HI', '93102'],
#  ['AL', '29627'],
#  ['TN', '68112'],
#  ['TX', '75493'],
#  ['MS', '64382'],
#  ['VT', '47099'],
#  ['FL', '87450'],
#  ['NE', '60938'],
#  ['NJ', '94248'],
#  ['TN', '59234'],
#  ['MN', '38430'],
#  ['MA', '32110'],
#  ['MO', '58453'],
#  ['ME', '43060'],
#  ['DE', '44288'],
#  ['AK', '76453'],
#  ['UT', '08945'],
#  ['NM', '77480'],
#  ['ND', '64886'],
#  ['MI', '73041'],
#  ['MD', '59304'],
#  ['AK', '72249'],
#  ['SD', '08559'],
#  ['NE', '96300'],
#  ['RI', '53889'],
#  ['NV', '46391'],
#  ['CO', '56330'],
#  ['MN', '37514'],
#  ['VT', '99408'],
#  ['WY', '37460'],
#  ['MS', '19093'],
#  ['CT', '41968'],
#  ['MD', '69392'],
#  ['SC', '15238'],
#  ['DC', '52797'],
#  ['IN', '06390'],
#  ['NE', '51210'],
#  ['NY', '07562'],
#  ['CA', '91552'],
#  ['DE', '26666'],
#  ['CT', '37704'],
#  ['WI', '87118'],
#  ['VT', '87014'],
#  ['GA', '64285'],
#  ['IA', '75602'],
#  ['MD', '92255'],
#  ['RI', '55379'],
#  ['AL', '30887'],
#  ['ID', '67242'],
#  ['AK', '92604'],
#  ['IL', '29749'],
#  ['DE', '63032'],
#  ['MD', '55348'],
#  ['MO', '98682'],
#  ['TX', '04469'],
#  ['MA', '62279'],
#  ['CA', '97733'],
#  ['MO', '39259'],
#  ['KS', '09837'],
#  ['WV', '99177'],
#  ['AZ', '11143'],
#  ['IN', '69031'],
#  ['MO', '27388'],
#  ['GA', '20222'],
#  ['WA', '58860'],
#  ['SD', '37384'],
#  ['NH', '95813'],
#  ['NE', '60827'],
#  ['MS', '19961'],
#  ['NC', '98345'],
#  ['OK', '69416'],
#  ['RI', '71955'],
#  ['AR', '34667'],
#  ['ND', '83410'],
#  ['AZ', '63751'],
#  ['TX', '58787'],
#  ['TN', '30095'],
#  ['SD', '87573'],
#  ['CT', '64653'],
#  ['KY', '50446'],
#  ['MD', '44325'],
#  ['NC', '86707'],
#  ['NH', '36813'],
#  ['OH', '77458'],
#  ['GA', '94018'],
#  ['MA', '49938'],
#  ['OH', '77901'],
#  ['ME', '32960'],
#  ['UT', '58189'],
#  ['KY', '03217'],
#  ['CA', '73750'],
#  ['WI', '17939'],
#  ['ID', '49545'],
#  ['CO', '92690'],
#  ['MN', '37391'],
#  ['WA', '62820'],
#  ['KS', '38167'],
#  ['WA', '89000'],
#  ['WY', '62208'],
#  ['PA', '46280'],
#  ['OR', '66112'],
#  ['NH', '90065'],
#  ['NM', '10210'],
#  ['OH', '75072'],
#  ['AZ', '53348'],
#  ['AL', '12926'],
#  ['ME', '62705'],
#  ['NM', '17467'],
#  ['MA', '26192'],
#  ['MD', '60015'],
#  ['DC', '91142'],
#  ['NC', '27087'],
#  ['TN', '84401'],
#  ['ID', '47897'],
#  ['NM', '47716'],
#  ['IL', '14704'],
#  ['CT', '32722'],
#  ['NV', '12104'],
#  ['MT', '58671'],
#  ['NH', '79429'],
#  ['ME', '10934'],
#  ['NJ', '49636'],
#  ['MS', '20227'],
#  ['OK', '77003'],
#  ['CA', '03643'],
#  ['MN', '85980'],
#  ['MI', '92559'],
#  ['FL', '65979'],
#  ['OK', '20389'],
#  ['WI', '32669'],
#  ['KY', '61692'],
#  ['CO', '98212'],
#  ['AR', '71885'],
#  ['VT', '61706'],
#  ['HI', '89949'],
#  ['MT', '98285'],
#  ['GA', '72399'],
#  ['LA', '70065'],
#  ['RI', '25912'],
#  ['MS', '83637'],
#  ['MA', '05593'],
#  ['KY', '06685'],
#  ['NV', '34121'],
#  ['ME', '10458'],
#  ['WY', '74175'],
#  ['AL', '01024'],
#  ['KS', '78234'],
#  ['NV', '42949'],
#  ['NV', '36477'],
#  ['CO', '45847'],
#  ['AZ', '78244'],
#  ['CA', '86173'],
#  ['VA', '04688'],
#  ['NM', '07642'],
#  ['NM', '49364'],
#  ['KS', '16484'],
#  ['TX', '81137'],
#  ['UT', '55993'],
#  ['RI', '63820'],
#  ['ME', '15133'],
#  ['NC', '80157'],
#  ['WY', '55084'],
#  ['MA', '72926'],
#  ['ND', '86671'],
#  ['VT', '87679'],
#  ['AR', '70563'],
#  ['AK', '87618'],
#  ['UT', '27222'],
#  ['IA', '15089'],
#  ['MA', '08841'],
#  ['IN', '84770'],
#  ['UT', '68575'],
#  ['AK', '44723'],
#  ['HI', '31740'],
#  ['VT', '88571'],
#  ['NV', '21963'],
#  ['UT', '96457'],
#  ['WI', '52255'],
#  ['HI', '39524'],
#  ['VA', '46530'],
#  ['TN', '32152'],
#  ['AL', '20213'],
#  ['RI', '43879'],
#  ['MD', '46214'],
#  ['MO', '72305'],
#  ['NM', '30139'],
#  ['MD', '87663'],
#  ['NJ', '96230'],
#  ['NH', '24920'],
#  ['FL', '39289'],
#  ['IL', '28101'],
#  ['OK', '05666'],
#  ['ME', '22074'],
#  ['IL', '46715'],
#  ['ND', '24794'],
#  ['NC', '68131'],
#  ['ND', '00592'],
#  ['DE', '92785'],
#  ['WV', '23443'],
#  ['HI', '82489'],
#  ['NY', '40664'],
#  ['FL', '82932'],
#  ['DC', '96960'],
#  ['DC', '74227'],
#  ['AR', '04978'],
#  ['HI', '05884'],
#  ['MT', '83974'],
#  ['IN', '75271'],
#  ['RI', '13623'],
#  ['NE', '66657'],
#  ['CO', '82892'],
#  ['AK', '94558'],
#  ['DC', '84066'],
#  ['NE', '84818'],
#  ['OK', '17173'],
#  ['IN', '71759'],
#  ['SD', '90567'],
#  ['KS', '80752'],
#  ['OK', '59407'],
#  ['WA', '68720'],
#  ['KS', '24032'],
#  ['NE', '21109'],
#  ['NH', '63451'],
#  ['VA', '84984'],
#  ['NJ', '96656'],
#  ['WV', '10037'],
#  ['KS', '81445'],
#  ['AZ', '93863'],
#  ['FL', '12523'],
#  ['IA', '55733'],
#  ['SD', '98772'],
#  ['TX', '05072'],
#  ['CA', '10238'],
#  ['TN', '58270'],
#  ['HI', '31385'],
#  ['IA', '82877'],
#  ['KS', '29285'],
#  ['ND', '88450'],
#  ['AL', '07394'],
#  ['IL', '87362'],
#  ['KS', '04491'],
#  ['CT', '49223'],
#  ['WA', '69860'],
#  ['OR', '05972'],
#  ['IN', '51531'],
#  ['MD', '53966'],
#  ['HI', '54285'],
#  ['IA', '38293'],
#  ['UT', '13653'],
#  ['DC', '72683'],
#  ['AK', '29974'],
#  ['GA', '76052'],
#  ['WV', '09134'],
#  ['CA', '28971'],
#  ['IA', '31777'],
#  ['AZ', '86613'],
#  ['WI', '59977'],
#  ['AK', '93518'],
#  ['GA', '17748'],
#  ['ND', '43735'],
#  ['KY', '94427'],
#  ['UT', '88781'],
#  ['NV', '37079'],
#  ['RI', '41838'],
#  ['NY', '85067'],
#  ['UT', '81458'],
#  ['AK', '48212'],
#  ['IA', '22652'],
#  ['MI', '93813'],
#  ['MD', '48491'],
#  ['WI', '16809'],
#  ['AL', '51900'],
#  ['UT', '61201'],
#  ['LA', '87935'],
#  ['RI', '13704'],
#  ['NM', '72613'],
#  ['IA', '99380'],
#  ['CT', '68503'],
#  ['WA', '35338'],
#  ['ME', '46673'],
#  ['WV', '74880'],
#  ['UT', '63759'],
#  ['ME', '44493'],
#  ['LA', '98858'],
#  ['AR', '63728'],
#  ['ND', '56829'],
#  ['AL', '83489'],
#  ['MO', '66813'],
#  ['HI', '01387'],
#  ['WA', '89156'],
#  ['NE', '47454'],
#  ['LA', '69951'],
#  ['VA', '31779'],
#  ['MD', '37908'],
#  ['OK', '10949'],
#  ['NH', '67890'],
#  ['SD', '12542'],
#  ['SC', '91966'],
#  ['NE', '27832'],
#  ['VA', '80868'],
#  ['SD', '23702'],
#  ['NE', '15018'],
#  ['AR', '25879'],
#  ['AK', '86398'],
#  ['WV', '31864'],
#  ['MA', '57556'],
#  ['NE', '87551'],
#  ['TX', '83235'],
#  ['KY', '11292'],
#  ['OH', '30683'],
#  ['PA', '23363'],
#  ['SD', '79534'],
#  ['TX', '33455'],
#  ['CO', '50300'],
#  ['PA', '46694'],
#  ['NE', '84433'],
#  ['MI', '26424'],
#  ['DC', '56752'],
#  ['MS', '81663'],
#  ['WY', '82164'],
#  ['WI', '83211'],
#  ['NY', '41821'],
#  ['PA', '28521'],
#  ['RI', '00957'],
#  ['MO', '80554'],
#  ['TN', '18266'],
#  ['NC', '87112'],
#  ['WY', '42022'],
#  ['NJ', '04830'],
#  ['VA', '77538'],
#  ['MO', '06637'],
#  ['ND', '25940'],
#  ['HI', '35059'],
#  ['HI', '25529'],
#  ['AZ', '73677'],
#  ['CT', '49594'],
#  ['DC', '43615'],
#  ['VA', '62054'],
#  ['NM', '90721'],
#  ['ME', '95000'],
#  ['NE', '25349'],
#  ['KS', '48059'],
#  ['CT', '29975'],
#  ['NH', '68613'],
#  ['IN', '28333'],
#  ['NC', '75361'],
#  ['MI', '18668'],
#  ['WY', '33057'],
#  ['MS', '34042'],
#  ['AZ', '53028'],
#  ['VT', '98495'],
#  ['AZ', '30171'],
#  ['CT', '28458'],
#  ['RI', '60858'],
#  ['AK', '36794'],
#  ['AK', '75880'],
#  ['NJ', '21655'],
#  ['NC', '90267'],
#  ['OH', '95736'],
#  ['AL', '55305'],
#  ['PA', '77684'],
#  ['NH', '28659'],
#  ['ID', '22814'],
#  ['ME', '89788'],
#  ['CO', '13164'],
#  ['HI', '56593'],
#  ['SC', '38144'],
#  ['NV', '81999'],
#  ['NE', '80405'],
#  ['SC', '15985'],
#  ['IN', '73907'],
#  ['NH', '46259'],
#  ['OK', '04197'],
#  ['NM', '83207'],
#  ['CT', '38781'],
#  ['VA', '92317'],
#  ['CA', '18123'],
#  ['MA', '89479'],
#  ['SC', '49681'],
#  ['CO', '14218'],
#  ['FL', '61350'],
#  ['NE', '36142'],
#  ['OK', '38401'],
#  ['TN', '18040'],
#  ['VA', '78615'],
#  ['MO', '29821'],
#  ['GA', '44592'],
#  ['MN', '45880'],
#  ['IN', '50026'],
#  ['IA', '28463'],
#  ['CA', '82927'],
#  ['IA', '54531'],
#  ['MI', '77373'],
#  ['WV', '84038'],
#  ['ID', '45641'],
#  ['OH', '76299'],
#  ['MS', '33754'],
#  ['KS', '11019']]

# %% [markdown]
# # Difficult way to parse address Post Directionals:

# %%
# rp=[]
# j='North Denise'
# for i in o:
#     if (re.findall(r'(W(est|\.|\s))|(E(ast|\.|\s))|(N(orth|\.|\s))|(S(outh|\.|\s)).?',
#            i,re.IGNORECASE)):
#         rp.append((re.findall(r'(W(est|\.|\s))|(E(ast|\.|\s))|(N(orth|\.|\s))|(S(outh|\.|\s)).?',
#            i,re.IGNORECASE)))
#     else:
#         rp.append([])
# rp
#

# %% [markdown]
# # Realistic Easy Way to Parse Post Directional;

# %%
# Post Directional:

post_dir=[]
dir=['North','South','East','West']
# bv=['North','Joseph']
# set(bv)&set(dir)

y=[]
for i in o:
    y.extend([i.split(' ')])
for j in y:
    if set(j)&set(dir):
        post_dir.append(list(set(j)&set(dir)))
    else:
        post_dir.append([])
post_dir[:6]
# Out:
# [[], [], ['North'], [], ['East'], []]

# %%
# Full Apt/suite if occurs otherwise empty list:

apt_ste=[]
for i in store_address:
    if re.findall(re.compile(r'\b(?=((Apt.|Suite)\s\w+))'),i):
        ui=re.findall(re.compile(r'\b(?=((Apt.|Suite)\s\w+))'),i)
        apt_ste.extend(ui)
    else:
        apt_ste.append([])
        
apt_ste_=[]

for i in apt_ste:
    if i==[]:
        apt_ste_.append([])
    else:
        apt_ste_.append(i[0])
        
apt_ste_
# apt_ste
# Out:
# ['Apt. 344',
#  'Apt. 421',
#  [],
#  'Apt. 200',
#  'Suite 648',
#  'Suite 506',
#  'Suite 647',
#  [],
#  [],
#  'Suite 768',
#  'Suite 654',
#  'Apt. 801',
#  'Suite 937',
#  'Suite 574',
#  'Suite 756',
#  [],
#  [],
#  'Suite 392',
#  [],
#  'Apt. 391',
#  'Suite 561',
#  'Suite 338',
#  [],
#  'Suite 626',
#  [],
#  [],
#  [],
#  'Suite 334',
#  'Apt. 236',
#  [],
#  'Suite 934',
#  [],
#  [],
#  [],
#  'Suite 997',
#  'Apt. 748',
#  [],
#  [],
#  'Suite 264',
#  'Apt. 486',
#  [],
#  'Apt. 996',
#  'Suite 176',
#  'Apt. 824',
#  'Apt. 567',
#  [],
#  'Apt. 487',
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  'Apt. 674',
#  'Suite 699',
#  [],
#  [],
#  [],
#  'Suite 399',
#  'Apt. 126',
#  [],
#  'Apt. 765',
#  [],
#  [],
#  [],
#  [],
#  [],
#  'Apt. 731',
#  'Suite 546',
#  'Apt. 808',
#  'Suite 101',
#  'Suite 779',
#  [],
#  [],
#  'Apt. 787',
#  'Suite 578',
#  [],
#  'Apt. 219',
#  [],
#  [],
#  'Apt. 976',
#  'Apt. 598',
#  [],
#  'Apt. 745',
#  'Suite 697',
#  [],
#  'Apt. 067',
#  'Suite 172',
#  [],
#  [],
#  [],
#  'Suite 177',
#  'Suite 567',
#  'Suite 588',
#  'Suite 288',
#  [],
#  [],
#  [],
#  [],
#  'Apt. 147',
#  [],
#  'Apt. 406',
#  [],
#  [],
#  'Suite 667',
#  'Suite 132',
#  [],
#  'Suite 900',
#  'Suite 873',
#  'Apt. 056',
#  [],
#  'Suite 528',
#  'Apt. 443',
#  'Apt. 857',
#  [],
#  [],
#  [],
#  [],
#  [],
#  'Suite 044',
#  'Apt. 900',
#  'Apt. 000',
#  'Apt. 377',
#  'Apt. 600',
#  [],
#  'Suite 758',
#  [],
#  [],
#  [],
#  'Apt. 190',
#  [],
#  [],
#  'Apt. 567',
#  'Apt. 367',
#  [],
#  'Suite 727',
#  [],
#  'Apt. 522',
#  'Apt. 666',
#  'Suite 484',
#  'Apt. 083',
#  [],
#  [],
#  [],
#  'Suite 892',
#  [],
#  [],
#  [],
#  'Apt. 571',
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  'Suite 606',
#  [],
#  'Suite 434',
#  [],
#  [],
#  'Apt. 230',
#  [],
#  [],
#  [],
#  'Suite 697',
#  'Apt. 772',
#  [],
#  [],
#  'Apt. 857',
#  'Apt. 756',
#  'Apt. 748',
#  'Apt. 868',
#  'Apt. 327',
#  [],
#  [],
#  [],
#  'Apt. 094',
#  'Apt. 386',
#  [],
#  [],
#  'Suite 794',
#  'Suite 376',
#  'Apt. 728',
#  [],
#  [],
#  'Suite 656',
#  [],
#  'Suite 778',
#  [],
#  'Apt. 646',
#  [],
#  'Apt. 080',
#  'Suite 693',
#  'Suite 079',
#  'Suite 386',
#  [],
#  [],
#  [],
#  'Apt. 193',
#  'Apt. 337',
#  'Apt. 261',
#  [],
#  [],
#  'Apt. 576',
#  [],
#  [],
#  [],
#  'Apt. 327',
#  [],
#  'Apt. 205',
#  [],
#  'Apt. 843',
#  [],
#  [],
#  'Apt. 765',
#  [],
#  [],
#  [],
#  [],
#  'Apt. 286',
#  [],
#  'Apt. 711',
#  'Suite 544',
#  'Apt. 279',
#  [],
#  'Apt. 729',
#  [],
#  [],
#  [],
#  'Apt. 850',
#  [],
#  'Apt. 080',
#  [],
#  'Suite 199',
#  'Apt. 237',
#  'Apt. 592',
#  'Apt. 796',
#  'Apt. 590',
#  [],
#  [],
#  'Apt. 099',
#  [],
#  [],
#  'Suite 029',
#  [],
#  'Suite 329',
#  'Apt. 851',
#  [],
#  'Apt. 073',
#  [],
#  [],
#  [],
#  [],
#  'Suite 048',
#  [],
#  [],
#  'Suite 715',
#  'Apt. 277',
#  'Suite 748',
#  [],
#  [],
#  [],
#  [],
#  'Suite 470',
#  [],
#  'Apt. 573',
#  [],
#  [],
#  [],
#  'Suite 752',
#  [],
#  [],
#  'Apt. 232',
#  [],
#  'Suite 049',
#  [],
#  [],
#  [],
#  'Suite 261',
#  [],
#  [],
#  [],
#  'Apt. 344',
#  [],
#  'Suite 469',
#  'Apt. 455',
#  'Suite 204',
#  'Apt. 601',
#  'Apt. 286',
#  'Suite 027',
#  [],
#  'Suite 529',
#  [],
#  'Apt. 550',
#  [],
#  [],
#  'Apt. 192',
#  [],
#  [],
#  'Apt. 288',
#  [],
#  'Suite 079',
#  'Apt. 155',
#  [],
#  [],
#  'Suite 471',
#  [],
#  'Suite 041',
#  [],
#  'Suite 699',
#  [],
#  [],
#  [],
#  'Apt. 774',
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  'Apt. 581',
#  'Suite 455',
#  [],
#  'Apt. 082',
#  'Apt. 098',
#  [],
#  [],
#  [],
#  [],
#  'Suite 996',
#  [],
#  'Suite 707',
#  'Apt. 355',
#  'Apt. 849',
#  'Apt. 406',
#  'Suite 524',
#  'Suite 774',
#  'Suite 662',
#  'Apt. 920',
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  'Apt. 286',
#  [],
#  [],
#  'Apt. 982',
#  'Apt. 241',
#  [],
#  [],
#  'Suite 000',
#  'Apt. 840',
#  [],
#  'Suite 600',
#  'Apt. 753',
#  [],
#  'Suite 561',
#  'Suite 077',
#  [],
#  'Apt. 744',
#  'Apt. 985',
#  'Apt. 931',
#  'Apt. 186',
#  'Suite 166',
#  [],
#  'Apt. 112',
#  [],
#  'Apt. 335',
#  'Apt. 042',
#  [],
#  [],
#  [],
#  [],
#  'Suite 966',
#  'Apt. 242',
#  'Suite 874',
#  'Suite 615',
#  'Apt. 020',
#  'Apt. 247',
#  [],
#  'Suite 193',
#  'Suite 190',
#  [],
#  'Apt. 647',
#  'Apt. 714',
#  'Apt. 720',
#  [],
#  'Suite 387',
#  'Suite 328',
#  'Suite 801',
#  [],
#  'Suite 088',
#  'Apt. 412',
#  'Apt. 010',
#  [],
#  'Apt. 601',
#  [],
#  'Suite 278',
#  [],
#  [],
#  'Suite 569',
#  'Suite 762',
#  [],
#  'Apt. 377',
#  [],
#  'Apt. 618',
#  'Suite 706',
#  [],
#  [],
#  'Apt. 186',
#  [],
#  'Suite 755',
#  'Suite 057',
#  [],
#  'Apt. 390',
#  'Suite 786',
#  [],
#  'Suite 118',
#  'Suite 001',
#  'Suite 795',
#  [],
#  'Apt. 892',
#  'Suite 809',
#  [],
#  [],
#  [],
#  'Suite 995',
#  'Suite 593',
#  [],
#  [],
#  'Apt. 184',
#  'Suite 521',
#  [],
#  [],
#  [],
#  [],
#  'Suite 025',
#  [],
#  [],
#  'Apt. 811',
#  'Suite 785',
#  'Suite 781',
#  'Suite 508',
#  'Apt. 764',
#  'Suite 304',
#  []]

# %% [markdown]
# # Military Addresses:

# %%
# for i in military_addr:
#     print(re.split(' ',i))
military_addr
# Out:
# ['USNV Maddox\nFPO AA 77402',
#  'USNV Lewis\nFPO AA 92743',
#  'USNV Wu\nFPO AE 47182',
#  'USNV Sloan\nFPO AP 06977',
#  'USS Chen\nFPO AA 10270',
#  'USNS Fischer\nFPO AE 45323',
#  'USS Glover\nFPO AP 69577',
#  'USNV Medina\nFPO AA 82238',
#  'USCGC Lee\nFPO AA 38102',
#  'USCGC Brady\nFPO AA 11924',
#  'USS Wright\nFPO AE 26620',
#  'USS Maynard\nFPO AE 46069',
#  'USCGC Wells\nFPO AP 17268',
#  'USCGC Vasquez\nFPO AE 08545',
#  'USNS Yoder\nFPO AP 83316']

# %% [markdown]
# # `Now you can just take what elements by index to create Military Address FIle:`

# %%
parse_mil_adrr=[]
for i in military_addr:
    parse_mil_adrr.append(i.split('\n'))

k=[]
for i,j in parse_mil_adrr:
    k.append([i.split(' '),j.split(' ')])
k
# Out:
# [[['USNV', 'Maddox'], ['FPO', 'AA', '77402']],
#  [['USNV', 'Lewis'], ['FPO', 'AA', '92743']],
#  [['USNV', 'Wu'], ['FPO', 'AE', '47182']],
#  [['USNV', 'Sloan'], ['FPO', 'AP', '06977']],
#  [['USS', 'Chen'], ['FPO', 'AA', '10270']],
#  [['USNS', 'Fischer'], ['FPO', 'AE', '45323']],
#  [['USS', 'Glover'], ['FPO', 'AP', '69577']],
#  [['USNV', 'Medina'], ['FPO', 'AA', '82238']],
#  [['USCGC', 'Lee'], ['FPO', 'AA', '38102']],
#  [['USCGC', 'Brady'], ['FPO', 'AA', '11924']],
#  [['USS', 'Wright'], ['FPO', 'AE', '26620']],
#  [['USS', 'Maynard'], ['FPO', 'AE', '46069']],
#  [['USCGC', 'Wells'], ['FPO', 'AP', '17268']],
#  [['USCGC', 'Vasquez'], ['FPO', 'AE', '08545']],
#  [['USNS', 'Yoder'], ['FPO', 'AP', '83316']]]

# %% [markdown]
# # Citations:
#
# https://pe.usps.com/text/pub28/28apd_002.htm  (USPS postal code) criteria
#
# https://github.com/scrapehero/yellowpages-scraper
#
# https://docs.python.org/3/library/re.html
#
# https://smartystreets.com/articles/regular-expressions-for-street-addresses
#
# https://stackoverflow.com/questions/11160192/how-to-parse-freeform-street-postal-address-out-of-text-and-into-components
#
# https://www.regular-expressions.info/wordboundaries.html
#
# https://www.regular-expressions.info/lookaround.html
